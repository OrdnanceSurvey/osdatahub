# %% [markdown]
# **JavaScript Developer?** The [JavaScript version of the `osdatahub` library](https://github.com/OrdnanceSurvey/osdatahub-js) makes it easy to use OS data in the browser or in NodeJS.

# %% [markdown]
# # Using the NGD Features API with Python
#
# The National Geographic Database (NGD) Features API provides access to Ordnance Survey's next generation NGD data.
# The NGD Features API is a premium or public sector product only. If you are looking to access free data, you should use the [OS Features API](https://osdatahub.os.uk/docs/wfs/overview).
#
# There are many ways to access the National Geographic Database:
# - If you'd like to download data using a GUI, [Select+Build](https://www.ordnancesurvey.co.uk/business-government/products/os-select-build), allows you to download multiple types of features at once, delivered as part of the [OS Data Hub](https://osdatahub.os.uk).
# - The [NGD Features API](https://www.ordnancesurvey.co.uk/business-government/products/os-ngd-api-features) allows for programatic access to NGD data in `GeoJSON` format.
#
# For Python developers, the [`osdatahub`](https://github.com/OrdnanceSurvey/osdatahub) Python library wraps almost all APIs in the [OS Data Hub](https://osdatahub.os.uk/) and provides an easy, Pythonic way to get data from Ordnance Survey. We have now added support for the NGD Features API, so you can access OS' latest product and next-generation data with only a few lines of Python code.

# %% [markdown]
# ## 1. Getting Started

# %% [markdown]
# ### 1.1 Importing your OS Data Hub API Key
# In order to access the NGD, you  must first have an OS Data Hub API key, a notebook explaining the process of registering an account and getting an API key is available to read [here](https://github.com/OrdnanceSurvey/osdatahub/blob/master/Examples/Setting%20up%20an%20API%20key.ipynb). When you're choosing which APIs you want to add to your project, you must select "OS NGD API - Features" to use NGD data.
#
#
# Once you have an API key, you can load your API key in by either passing it in as a string, or setting it as an environment variable. We recommend using the [`python-dotenv`](https://pypi.org/project/python-dotenv/) library to securely store your API keys in a `.env` file without risk of accidentally committing them in your repo (by adding it to your `.gitignore` file).
#
# To use the `python-dotenv` package, simply:
# 1. Install with pip: `pip install python-dotenv`
# 2. Create a `.env` file in the root directory of your project
# 3. Add your API key to the file: `OS_API_KEY=[YOUR API KEY HERE]`

# %%
# Option 1: Assign as a string
# This is less secure, you may commit your API key by accident!
key = "YOUR API KEY HERE"

# Option 2: Use python-dotenv
# This will load environment variables into memory from a .env file
from dotenv import load_dotenv
from os import environ
load_dotenv()
key = environ.get("OS_API_KEY")

# %% [markdown]
# Nice one! We can now read the contents of the `key` variable to make sure that worked as expected:

# %%
# 🔎 run this cell to view your API key:
print(f'🔑 Your OS Data Hub key is {key}')

# %% [markdown]
# ### 1.2 Importing the NGD Module
# To import the NGD module from `osdatahub`, write the following:

# %%
from osdatahub import NGD

# %% [markdown]
# ## 2. Discovering Collections
# The NGD contains multiple themes and collections:
# - A `theme` is a family of `collections`, for example, there is a theme called 'Buildings'.
# - A `collection` is a group of features. The Buildings theme contains two collections: 'BuildingLine' and 'BuildingPart'.
#
# You can read more about the NGD Features API's themes and collections in the [Technical Specification](https://osdatahub.os.uk/docs/ofa/technicalSpecification).

# %% [markdown]
# To quickly retrieve a list of available data, you can query the API directly using the `NGD` module we previously imported:

# %%
ngd_collections = NGD.get_collections()

# %% [markdown]
# This will return a JSON object, which we can then interate through to return metadata about each collection.

# %%
# 🔎 run this cell to view a list of all available NGD collections
for collection in ngd_collections['collections']:
    print(f' - {collection["title"]} ({collection["id"]})')
# Out:
#  - Building Line (bld-fts-buildingline)
#  - Building Part (bld-fts-buildingpart)
#  - Named Area (gnm-fts-namedarea)
#  - Named Point (gnm-fts-namedpoint)
#  - Land (lnd-fts-land)
#  - Landform (lnd-fts-landform)
#  - Landform Line (lnd-fts-landformline)
#  - Landform Point (lnd-fts-landformpoint)
#  - Land Point (lnd-fts-landpoint)
#  - Site (lus-fts-site)
#  - Site Access Location (lus-fts-siteaccesslocation)
#  - Site Routing Point (lus-fts-siteroutingpoint)
#  - Compound Structure (str-fts-compoundstructure)
#  - Structure (str-fts-structure)
#  - Structure Line (str-fts-structureline)
#  - Structure Point (str-fts-structurepoint)
#  - Cartographic Rail Detail (trn-fts-cartographicraildetail)
#  - Rail (trn-fts-rail)
#  - Road Line (trn-fts-roadline)
#  - Road Track Or Path (trn-fts-roadtrackorpath)
#  - Connecting Link (trn-ntwk-connectinglink)
#  - Connecting Node (trn-ntwk-connectingnode)
#  - Ferry Link (trn-ntwk-ferrylink)
#  - Ferry Node (trn-ntwk-ferrynode)
#  - Ferry Terminal (trn-ntwk-ferryterminal)
#  - Path (trn-ntwk-path)
#  - Path Link (trn-ntwk-pathlink)
#  - Path Node (trn-ntwk-pathnode)
#  - Road (trn-ntwk-road)
#  - Road Junction (trn-ntwk-roadjunction)
#  - Road Link (trn-ntwk-roadlink)
#  - Road Node (trn-ntwk-roadnode)
#  - Street (trn-ntwk-street)
#  - Highway Dedication (trn-rami-highwaydedication)
#  - Maintenance Area (trn-rami-maintenancearea)
#  - Maintenance Line (trn-rami-maintenanceline)
#  - Maintenance Point (trn-rami-maintenancepoint)
#  - Reinstatement Area (trn-rami-reinstatementarea)
#  - Reinstatement Line (trn-rami-reinstatementline)
#  - Reinstatement Point (trn-rami-reinstatementpoint)
#  - Restriction (trn-rami-restriction)
#  - Routing Hazard (trn-rami-routinghazard)
#  - RoutingStructure (trn-rami-routingstructure)
#  - Special Designation Area (trn-rami-specialdesignationarea)
#  - Special Designation Line (trn-rami-specialdesignationline)
#  - Special Designation Point (trn-rami-specialdesignationpoint)
#  - Inter Tidal Line (wtr-fts-intertidalline)
#  - Tidal Boundary (wtr-fts-tidalboundary)
#  - Water (wtr-fts-water)
#  - Water Point (wtr-fts-waterpoint)
#  - Water Link (wtr-ntwk-waterlink)
#  - Water Link Set (wtr-ntwk-waterlinkset)
#  - Water Node (wtr-ntwk-waternode)

# %% [markdown]
# ## 3. Loading NGD Data into a GeoDataFrame
# We'll now walk through the process of acquiring data from the NGD Building Part collection (`bld-fts-buildingpart`) and importing this data into a GeoDataFrame.

# %% [markdown]
# ### 3.1 Requesting NGD Data
# To get the first 100 features in the collection, you simply need to make an `NGD` object and then run the `query()` method:

# %%
collection = "bld-fts-buildingpart"
ngd_building_part = NGD(key, collection)

# make the query and contact the API
features = ngd_building_part.query()

# %% [markdown]
# The API returns an OGC-compliant GeoJSON, which is easy to import into other libraries for analysis.

# %% [markdown]
# ### 3.2 Importing into a GeoDataFrame
# If you haven't already, import the `geopandas` library:

# %%
import geopandas as gpd

# %% [markdown]
# And now, import the NGD data using the `.from_features` function.

# %%
gdf = gpd.GeoDataFrame.from_features(features)

# %% [markdown]
# Let's take a look at a preview of the data (the `.head` function). As you'll see, NGD data is rich in attribution:

# %%
# 🔎 run this cell to preview the contents of the GeoDataFrame
gdf.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((-3.97031 55.74255, -3.97019 55.74249...
# 1  POLYGON ((1.72756 52.66142, 1.72755 52.66144, ...
# 2  POLYGON ((0.19415 51.59241, 0.19411 51.59241, ...
# 3  POLYGON ((-1.45472 52.39610, -1.45479 52.39613...
# 4  POLYGON ((0.93898 52.81772, 0.93900 52.81767, ...
#
#                                    osid                  toid      theme  \
# 0  000000b1-0556-4231-a52a-9b5b8b82dfbf     osgb1000041024621  Buildings
# 1  00000183-3ae0-4f05-adb8-a5792d09f55f  osgb5000005167584940  Buildings
# 2  000001d6-8217-4f7a-a70e-3757eb76c9e4     osgb1000000360448  Buildings
# 3  00000208-a659-49f9-a587-ab26cb2b2248     osgb1000017249389  Buildings
# 4  00000246-42c8-4e23-982e-15613e0fd2fe     osgb1000008341371  Buildings
#
#             changetype  isobscured description versiondate  geometry_area  \
# 0  Modified Attributes       False    Building  2022-09-18      59.200650
# 1                  New       False    Building  2022-08-26       9.499142
# 2                  New       False    Building  2022-08-26      15.258750
# 3                  New       False    Building  2022-08-26      12.806250
# 4                  New       False    Building  2022-08-26      58.280086
#
#      height_source  ... absoluteheightroofbase description_updatedate  \
# 0  Ordnance Survey  ...                 110.85             2006-08-30
# 1  Ordnance Survey  ...                   6.21             2015-10-29
# 2  Ordnance Survey  ...                  37.13             1993-04-01
# 3  Ordnance Survey  ...                  71.95             1993-05-01
# 4  Ordnance Survey  ...                  54.46             2005-04-30
#
#   oslandcover_updatedate oslanduse_evidencedate relativeheightroofbase  \
# 0             2006-08-30             2006-08-30                   5.85
# 1             2015-10-29             2015-03-11                   0.82
# 2             1993-04-01             1993-04-01                   2.43
# 3             1993-05-01             1993-05-01                   1.96
# 4             2005-04-30             2005-04-30                   3.61
#
#   versionavailabletodate firstdigitalcapturedate description_evidencedate  \
# 0                   None              1991-09-18               2006-08-30
# 1                   None              2015-11-12               2015-03-11
# 2                   None              1993-04-01               1993-04-01
# 3                   None              1993-05-01               1993-05-01
# 4                   None              1992-03-13               2005-04-30
#
#   oslandcover_evidencedate versionavailablefromdate
# 0               2006-08-30     2022-09-19T00:00:00Z
# 1               2015-03-11     2022-08-27T00:00:00Z
# 2               1993-04-01     2022-08-27T00:00:00Z
# 3               1993-05-01     2022-08-27T00:00:00Z
# 4               2005-04-30     2022-08-27T00:00:00Z
#
# [5 rows x 40 columns]

# %% [markdown]
# You can learn more about importing data from the `osdatahub` package into other common Python libraries [in this example](https://github.com/OrdnanceSurvey/osdatahub/blob/master/Examples/Plotting%20API%20Results%20-%20GeoPandas%2C%20Matplotlib%20and%20Contextily.ipynb).

# %% [markdown]
# ## 4. Adding Filters
#
# Filters can help you limit the scope of your query, using spatial, temporal and contextual parameters.
# The NGD Features API uses Common Query Language (CQL) to allow you to filter data using the attribution set of each collection.
#
# - Spatial: `extent`
# You can specify any polygon to query by using the `Extent` class. You can learn more about using `Extent` [here](https://github.com/OrdnanceSurvey/osdatahub/blob/master/Examples/Defining%20Extents%20for%20API%20Queries.ipynb)
#
# - Temporal: `start_datetime` and `end_datetime`
# If you want to only get features that have a temporal property, you can specify date ranges to query within. If you want to get features for a single time, simply provide the same argument for both parameters.
#
# - Contextual: `cql_filter`
# The NGD API supports a generic filter grammar called the Common Query Language (CQL) to further filter your query using human readable commands. You can find out more about the operations that the API supports in the Queryables section of the [Technical Specification](https://osdatahub.os.uk/docs/ofa/technicalSpecification). The CQL filter allows you to specify specific properties for features as well as spatial filters.
#
# In addition, the `osdatahub` library permits you to specify the maximum number of features to return (by default, 100 features):
#
# - `max_results`
# Allows you to specify the maximum number of features you'd like to receive. Default is 100.
#
# - `offset`
# Skips past the specified number of features in the collection. Default is 0.

# %% [markdown]
# ### 4.1 Specifying an Extent (Bounding Box)
#
# In our case, we want to get features that are only within a certain bounding box in Manchester.
# We can specify an extent using the `Extent` submodule:

# %%
from osdatahub import Extent

# %% [markdown]
# Now we can use the `Extent` module to specify the geometry, and then pass this into the `ngdBuildingPart` query:

# %%
extent = Extent.from_bbox((-2.244973,53.476620,-2.237799,53.480525), crs="CRS84")
features = ngd_building_part.query(extent=extent)

# 🔎 run this cell to see the contents of 'features'
features
# Out:
# {'type': 'FeatureCollection',
#  'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?limit=100&filter=INTERSECTS%28geometry%2C%20POLYGON%20%28%28-2.237799%2053.47662%2C%20-2.237799%2053.480525%2C%20-2.244973%2053.480525%2C%20-2.244973%2053.47662%2C%20-2.237799%2053.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FOGC%2F1.3%2FCRS84',
#    'rel': 'self',
#    'type': 'application/geo+json',
#    'title': "All features from the 'Building Part' collection"},
#   {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?offset=100&limit=100&filter=INTERSECTS%28geometry%2C%20POLYGON%20%28%28-2.237799%2053.47662%2C%20-2.237799%2053.480525%2C%20-2.244973%2053.480525%2C%20-2.244973%2053.47662%2C%20-2.237799%2053.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FOGC%2F1.3%2FCRS84',
#    'rel': 'next',
#    'type': 'application/geo+json',
#    'title': 'Next page'}],
#  'timeStamp': '2022-11-08T12:44:23.015222Z',
#  'numberReturned': 100,
#  'features': [{'id': '02837688-4553-4d32-87aa-10733dad9274',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2409815, 53.4790683],
#       [-2.2410231, 53.4790893],
#       [-2.2410816, 53.4790478],
#       [-2.2410546, 53.4790343],
#       [-2.2410468, 53.4790304],
#       [-2.2410408, 53.4790272],
#       [-2.2409815, 53.4790683]]]},
#    'properties': {'osid': '02837688-4553-4d32-87aa-10733dad9274',
#     'toid': 'osgb1000024157902',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 21.57975,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2016-10-26',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 68.98,
#     'absoluteheightminimum': 43.34,
#     'geometry_evidencedate': '2016-10-04',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 25.64,
#     'absoluteheightroofbase': 66.54,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 23.2,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '02c6f2c7-0e25-4224-b4a7-c62c7d476e48',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2413512, 53.479827],
#       [-2.2412429, 53.4798623],
#       [-2.2412301, 53.4798713],
#       [-2.2412114, 53.479888],
#       [-2.2412115, 53.4799158],
#       [-2.2415417, 53.4800837],
#       [-2.241596, 53.4800831],
#       [-2.241707, 53.4800056],
#       [-2.2416882, 53.4799971],
#       [-2.2413512, 53.479827]]]},
#    'properties': {'osid': '02c6f2c7-0e25-4224-b4a7-c62c7d476e48',
#     'toid': 'osgb1000024157913',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 441.13125,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-13',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-13',
#     'absoluteheightmaximum': 67.69,
#     'absoluteheightminimum': 44.22,
#     'geometry_evidencedate': '2010-04-13',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 23.47,
#     'absoluteheightroofbase': 60.87,
#     'description_updatedate': '2010-04-13',
#     'oslandcover_updatedate': '2010-04-13',
#     'oslanduse_evidencedate': '2010-04-13',
#     'relativeheightroofbase': 16.65,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-13',
#     'oslandcover_evidencedate': '2010-04-13',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0364fa8b-024a-4078-ae13-4a3e21c5e744',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2400737, 53.4781353],
#       [-2.2401765, 53.4780632],
#       [-2.2399967, 53.4779687],
#       [-2.2398811, 53.4780359],
#       [-2.2400737, 53.4781353]]]},
#    'properties': {'osid': '0364fa8b-024a-4078-ae13-4a3e21c5e744',
#     'toid': 'osgb1000024155721',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 173.9625,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 57.17,
#     'absoluteheightminimum': 42.16,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 15.01,
#     'absoluteheightroofbase': 52.83,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 10.67,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '04b6b1d7-2a73-4173-b953-20c3ef2e6ce7',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2377298, 53.4769175],
#       [-2.2377304, 53.4769179],
#       [-2.2378319, 53.4769761],
#       [-2.2378824, 53.4769448],
#       [-2.2377808, 53.4768865],
#       [-2.2377802, 53.4768862],
#       [-2.2377298, 53.4769175]]]},
#    'properties': {'osid': '04b6b1d7-2a73-4173-b953-20c3ef2e6ce7',
#     'toid': 'osgb5000005290155401',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-26',
#     'geometry_area': 45.440587,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2021-11-30',
#     'height_evidencedate': None,
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2021-11-30',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '2021-11-30',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '2021-11-30',
#     'oslandcover_updatedate': '2021-11-30',
#     'oslanduse_evidencedate': '2021-11-30',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2021-11-30',
#     'description_evidencedate': '2021-11-30',
#     'oslandcover_evidencedate': '2021-11-30',
#     'versionavailablefromdate': '2022-09-27T00:00:00Z'}},
#   {'id': '050aaf7a-2fd2-43f8-a8cf-7594b3b85059',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2420557, 53.4774865],
#       [-2.2420177, 53.4774669],
#       [-2.2420089, 53.477473],
#       [-2.2420468, 53.4774927],
#       [-2.2420557, 53.4774865]]]},
#    'properties': {'osid': '050aaf7a-2fd2-43f8-a8cf-7594b3b85059',
#     'toid': 'osgb1000024155885',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 2.9989,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1998-12-09',
#     'height_evidencedate': None,
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1998-12-09',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '1998-12-09',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '1998-12-09',
#     'oslandcover_updatedate': '1998-12-09',
#     'oslanduse_evidencedate': '1998-12-09',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1998-12-09',
#     'description_evidencedate': '1998-12-09',
#     'oslandcover_evidencedate': '1998-12-09',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '056a3df2-4fb1-4e8f-a762-ea84f372d9bc',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2410075, 53.4776255],
#       [-2.2410643, 53.4776552],
#       [-2.241189, 53.4775644],
#       [-2.2411606, 53.4775504],
#       [-2.2411378, 53.4775392],
#       [-2.2411308, 53.4775358],
#       [-2.2411136, 53.4775484],
#       [-2.2410075, 53.4776255]]]},
#    'properties': {'osid': '056a3df2-4fb1-4e8f-a762-ea84f372d9bc',
#     'toid': 'osgb1000002517090806',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area':

#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 227.9475,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 63.14,
#     'absoluteheightminimum': 43.17,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 19.97,
#     'absoluteheightroofbase': 59.93,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 16.76,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0abc599b-0910-4295-af12-0bf42aae3bde',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2380056, 53.4775785],
#       [-2.2379935, 53.4775718],
#       [-2.237974, 53.4775849],
#       [-2.2379718, 53.4775863],
#       [-2.2378178, 53.4776814],
#       [-2.2380015, 53.4777884],
#       [-2.2380068, 53.4777848],
#       [-2.2380219, 53.4777929],
#       [-2.2380782, 53.4777586],
#       [-2.238091, 53.4777653],
#       [-2.2381849, 53.4777067],
#       [-2.2381939, 53.4777013],
#       [-2.238172, 53.4776861],
#       [-2.238181, 53.4776802],
#       [-2.2380434, 53.4776],
#       [-2.2380056, 53.4775785]]]},
#    'properties': {'osid': '0abc599b-0910-4295-af12-0bf42aae3bde',
#     'toid': 'osgb1000024155686',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Multistorey Car Park',
#     'versiondate': '2022-08-26',
#     'geometry_area': 320.615,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Transport: Road, Track Or Path',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2005-11-09',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2021-02-15',
#     'absoluteheightmaximum': 58.81,
#     'absoluteheightminimum': 42.23,
#     'geometry_evidencedate': '2005-11-09',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 16.58,
#     'absoluteheightroofbase': 57.88,
#     'description_updatedate': '2021-02-15',
#     'oslandcover_updatedate': '2021-02-15',
#     'oslanduse_evidencedate': '2021-02-15',
#     'relativeheightroofbase': 15.65,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2021-02-15',
#     'oslandcover_evidencedate': '2021-02-15',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0b348487-5ce5-444d-ae1f-2965fe8bd34b',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2400792, 53.4765593],
#       [-2.2401849, 53.4767397],
#       [-2.2404209, 53.4766273],
#       [-2.2403463, 53.4765016],
#       [-2.2403245, 53.4765062],
#       [-2.2403034, 53.4765107],
#       [-2.2402809, 53.4765152],
#       [-2.240183, 53.4765352],
#       [-2.2400784, 53.476557],
#       [-2.2400792, 53.4765593]]]},
#    'properties': {'osid': '0b348487-5ce5-444d-ae1f-2965fe8bd34b',
#     'toid': 'osgb1000024155788',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 343.31625,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2005-11-22',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2005-11-22',
#     'absoluteheightmaximum': 61.14,
#     'absoluteheightminimum': 38.45,
#     'geometry_evidencedate': '2005-11-22',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 22.69,
#     'absoluteheightroofbase': 55.82,
#     'description_updatedate': '2005-11-22',
#     'oslandcover_updatedate': '2005-11-22',
#     'oslanduse_evidencedate': '2005-11-22',
#     'relativeheightroofbase': 17.37,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2005-11-22',
#     'oslandcover_evidencedate': '2005-11-22',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0ca78640-db9b-4fa0-ae11-e2c1fb76d5b4',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.24262, 53.4799705],
#       [-2.2426681, 53.4799479],
#       [-2.2426613, 53.479943],
#       [-2.2427214, 53.4799132],
#       [-2.2426805, 53.479881],
#       [-2.2425693, 53.4799315],
#       [-2.2425753, 53.479936],
#       [-2.24262, 53.4799705]]]},
#    'properties': {'osid': '0ca78640-db9b-4fa0-ae11-e2c1fb76d5b4',
#     'toid': 'osgb1000024085498',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 46.045,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 60.82,
#     'absoluteheightminimum': 43.39,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 17.43,
#     'absoluteheightroofbase': 52.69,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 9.3,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '

#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 15.89,
#     'absoluteheightroofbase': 54.66,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 10.59,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0e894ea4-4e81-4f9a-84a5-0937fb5cf562',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2430721, 53.4783788],
#       [-2.2432224, 53.478274],
#       [-2.2432294, 53.4782657],
#       [-2.2432309, 53.4782598],
#       [-2.2432305, 53.4782561],
#       [-2.2432266, 53.4782484],
#       [-2.2432252, 53.4782468],
#       [-2.2432172, 53.4782405],
#       [-2.2432141, 53.4782388],
#       [-2.2432029, 53.4782348],
#       [-2.2432011, 53.4782345],
#       [-2.2431919, 53.4782344],
#       [-2.2431871, 53.4782348],
#       [-2.2431769, 53.478236],
#       [-2.2431743, 53.4782366],
#       [-2.2431612, 53.4782424],
#       [-2.2429692, 53.4783815],
#       [-2.2429601, 53.4783895],
#       [-2.2429593, 53.4783906],
#       [-2.2429563, 53.4783987],
#       [-2.2429593, 53.4784066],
#       [-2.2429644, 53.4784114],
#       [-2.2429683, 53.4784138],
#       [-2.2429699, 53.4784144],
#       [-2.2429812, 53.4784182],
#       [-2.2429863, 53.4784192],
#       [-2.2429962, 53.4784202],
#       [-2.243004, 53.4784202],
#       [-2.2430165, 53.478418],
#       [-2.2430721, 53.4783788]]]},
#    'properties': {'osid': '0e894ea4-4e81-4f9a-84a5-0937fb5cf562',
#     'toid': 'osgb5000005192537919',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Shelter',
#     'versiondate': '2022-08-26',
#     'geometry_area': 125.754097,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2016-10-26',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2016-10-26',
#     'absoluteheightmaximum': 44.68,
#     'absoluteheightminimum': 40.8,
#     'geometry_evidencedate': '2016-10-04',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 3.88,
#     'absoluteheightroofbase': 42.19,
#     'description_updatedate': '2016-10-26',
#     'oslandcover_updatedate': '2016-10-26',
#     'oslanduse_evidencedate': '2016-10-04',
#     'relativeheightroofbase': 1.39,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2016-11-01',
#     'description_evidencedate': '2016-10-04',
#     'oslandcover_evidencedate': '2016-10-04',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0f2db9e2-953a-452f-ba7b-c8bead0d9590',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2427611, 53.4790858],
#       [-2.2428189, 53.4790434],
#       [-2.2425978, 53.4789323],
#       [-2.2425487, 53.4789662],
#       [-2.242542, 53.4789707],
#       [-2.2425488, 53.4789757],
#       [-2.2425541, 53.4789779],
#       [-2.2427611, 53.4790858]]]},
#    'properties': {'osid': '0f2db9e2-953a-452f-ba7b-c8bead0d9590',
#     'toid': 'osgb1000024085455',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 113.81675,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-12',
#     'absoluteheightmaximum': 60.59,
#     'absoluteheightminimum': 41.78,
#     'geometry_evidencedate': '2010-04-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 18.81,
#     'absoluteheightroofbase': 55.29,
#     'description_updatedate': '2010-04-12',
#     'oslandcover_updatedate': '2010-04-12',
#     'oslanduse_evidencedate': '2010-04-12',
#     'relativeheightroofbase': 13.51,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-12',
#     'oslandcover_evidencedate': '2010-04-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0fe6b99d-f1b1-492a-95ed-684dc5f1825f',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2385122, 53.4793941],
#       [-2.2385394, 53.479407],
#       [-2.2385807, 53.4793768],
#       [-2.2385565, 53.479363],
#       [-2.2385122, 53.4793941]]]},
#    'properties': {'osid': '0fe6b99d-f1b1-492a-95ed-684dc5f1825f',
#     'toid': 'osgb1000024157952',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 10.055,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 48.05,
#     'absoluteheightminimum': 44.57,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 3.48,
#     'absoluteheightroofbase': 47.4,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 2.83,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0fee2ca7-da91-459b-9283-8abbbfba463f',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2396766, 53.4767708],
#       [-2.2396501, 53.4767484],
#       [-2.2397801, 53.4766942],
#       [-2.23979, 53.4767036],
#       [-2.2398028, 53.4766986],
#       [-2.2397259, 53.4765631],
#       [-2.2396928, 53.4765775],
#       [-2.2394298, 53.4766913],
#       [-2.2394299, 53.4767147],
#       [-2.2395519, 53.4768268],
#       [-2.2396766, 53.4767708]]]},
#    'properties': {'osid': '0fee2ca7-da91-459b-9283-8abbbfba463f',
#     'toid': 'osgb1000024155802',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 361.7775,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 62.66,
#     'absoluteheightminimum': 39.43,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 23.23,
#     'absoluteheightroofbase': 56.69,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 17.26,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '105e3a2c-6b26-42a6-9b1b-b777d1a7bc41',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2393488, 53.4783668],
#       [-2.2394538, 53.4784219],
#       [-2.239444, 53.4784291],
#       [-2.2395536, 53.4784855],
#       [-2.2395686, 53.4784747],
#       [-2.2396114, 53.4784445],
#       [-2.2396241, 53.4784351],
#       [-2.239609, 53.478427],
#       [-2.2396668, 53.478386],
#       [-2.2396976, 53.4783639],
#       [-2.2397568, 53.4783211],
#       [-2.2395611, 53.478219],
#       [-2.2393488, 53.4783668]]]},
#    'properties': {'osid': '105e3a2c-6b26-42a6-9b1b-b777d1a7bc41',
#     'toid': 'osgb1000024155853',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 395.76,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 65.25,
#     'absoluteheightminimum': 42.3,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 22.95,
#     'absoluteheightroofbase': 48.48,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 6.18,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '111de178-876e-480a-b144-0c68c9cd0860',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.243804, 53.4799164],
#       [-2.243644, 53.4799891],
#       [-2.24365, 53.479994],
#       [-2.2437302, 53.4800568],
#       [-2.2438354, 53.4800089],
#       [-2.2438445, 53.4800152],
#       [-2.2438918, 53.4799927],
#       [-2.2438146, 53.4799259],
#       [-2.243804, 53.4799164]]]},
#    'properties': {'osid': '111de178-876e-480a-b144-0c68c9cd0860',
#     'toid': 'osgb1000024085466',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 127.62625,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-12',
#     'absoluteheightmaximum': 58.39,
#     'absoluteheightminimum': 41.66,
#     'geometry_evidencedate': '2010-04-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 16.73,
#     'absoluteheightroofbase': 50.23,
#     'description_updatedate': '2010-04-12',
#     'oslandcover_updatedate': '2010-04-12',
#     'oslanduse_evidencedate': '2010-04-12',
#     'relativeheightroofbase': 8.57,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-12',
#     'oslandcover_evidencedate': '2010-04-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '116ab673-715b-4cd4-8143-52e6450e00df',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2421383, 53.4773838],
#       [-2.2423155, 53.4774765],
#       [-2.2423189, 53.4774783],
#       [-2.2424434, 53.4773917],
#       [-2.2422643, 53.4772973],
#       [-2.2421383, 53.4773838]]]},
#    'properties': {'osid': '116ab673-715b-4cd4-8143-52e6450e00df',
#     'toid': 'osgb1000024155771',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 202.298,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-28',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-28',
#     'absoluteheightmaximum': 61.95,
#     'absoluteheightminimum': 40.14,
#     'geometry_evidencedate': '2010-04-28',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 21.81,
#     'absoluteheightroofbase': 57.58,
#     'description_updatedate': '2010-04-28',
#     'oslandcover_updatedate': '2010-04-28',
#     'oslanduse_evidencedate': '2010-04-28',
#     'relativeheightroofbase': 17.44,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-28',
#     'oslandcover_evidencedate': '2010-04-28',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '1419b9a3-836d-43a0-9420-a53740ddc908',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2378461, 53.4769981],
#       [-2.2379586, 53.477063],
#       [-2.2380101, 53.4770307],
#       [-2.2379213, 53.4769788],
#       [-2.2379028, 53.476968],
#       [-2.2378982, 53.4769658],
#       [-2.2378645, 53.476987],
#       [-2.2378461, 53.4769981]]]},
#    'properties': {'osid': '1419b9a3-836d-43a0-9420-a53740ddc908',
#     'toid': 'osgb1000002517088106',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 51.7192,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
# ...
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2009-07-23',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2009-07-23',
#     'absoluteheightmaximum': 79.08,
#     'absoluteheightminimum': 42.84,
#     'geometry_evidencedate': '2009-07-23',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 36.24,
#     'absoluteheightroofbase': 70.42,
#     'description_updatedate': '2009-07-23',
#     'oslandcover_updatedate': '2009-07-23',
#     'oslanduse_evidencedate': '2009-07-23',
#     'relativeheightroofbase': 27.58,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2009-07-23',
#     'description_evidencedate': '2009-07-23',
#     'oslandcover_evidencedate': '2009-07-23',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '474ac162-c822-40c7-a33c-7fe15b97804e',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2415845, 53.4776361],
#       [-2.2415409, 53.4776668],
#       [-2.2415259, 53.4776776],
#       [-2.2415101, 53.4776704],
#       [-2.2414448, 53.4777191],
#       [-2.2414954, 53.4777451],
#       [-2.2414857, 53.4777527],
#       [-2.2415189, 53.4777697],
#       [-2.2415594, 53.4777409],
#       [-2.241632, 53.4777781],
#       [-2.2417295, 53.4777109],
#       [-2.2415845, 53.4776361]]]},
#    'properties': {'osid': '474ac162-c822-40c7-a33c-7fe15b97804e',
#     'toid': 'osgb1000024155759',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 156.56375,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Utility Or Environmental Protection',
#     'oslandusetierb': ['Telecommunications'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2005-11-09',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2005-11-09',
#     'absoluteheightmaximum': 50.12,
#     'absoluteheightminimum': 41.24,
#     'geometry_evidencedate': '2005-11-09',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 8.88,
#     'absoluteheightroofbase': 46.55,
#     'description_updatedate': '2005-11-09',
#     'oslandcover_updatedate': '2005-11-09',
#     'oslanduse_evidencedate': '2005-11-09',
#     'relativeheightroofbase': 5.31,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2005-11-09',
#     'oslandcover_evidencedate': '2005-11-09',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '476f7cd9-c2c0-47a1-8764-7bc2bac2b07c',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2401902, 53.4782101],
#       [-2.2404425, 53.4783422],
#       [-2.2404973, 53.4783034],
#       [-2.2402434, 53.4781727],
#       [-2.2401902, 53.4782101]]]},
#    'properties': {'osid': '476f7cd9-c2c0-47a1-8764-7bc2bac2b07c',
#     'toid': 'osgb1000024155732',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 123.59875,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 56.25,
#     'absoluteheightminimum': 42.21,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 14.04,
#     'absoluteheightroofbase': 55.47,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 13.26,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '477c48ae-a130-4ac2-ba10-67780b82aaa2',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2424653, 53.4807393],
#       [-2.2424691, 53.4807303],
#       [-2.2424887, 53.4807321],
#       [-2.2425575, 53.4805203],
#       [-2.2425709, 53.480478],
#       [-2.2425572, 53.4804677],
#       [-2.2422112, 53.4804293],
#       [-2.2422089, 53.4804297],
#       [-2.2421964, 53.4804707],
#       [-2.242173, 53.4804671],
#       [-2.2421147, 53.480687],
#       [-2.2421381, 53.4806896],
#       [-2.2421344, 53.4807049],
#       [-2.2424653, 53.4807393]]]},
#    'properties': {'osid': '477c48ae-a130-4ac2-ba10-67780b82aaa2',
#     'toid': 'osgb1000024158054',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 786.23875,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-12',
#     'absoluteheightmaximum': 90.0,
#     'absoluteheightminimum': 44.21,
#     'geometry_evidencedate': '2010-04-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 45.79,
#     'absoluteheightroofbase': 71.58,
#     'description_updatedate': '2010-04-12',
#     'oslandcover_updatedate': '2010-04-12',
#     'oslanduse_evidencedate': '2010-04-12',
#     'relativeheightroofbase': 27.37,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-12',
#     'oslandcover_evidencedate': '2010-04-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '478961e4-67ae-486c-8829-524ef282f003',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2433556, 53.4805528],
#       [-2.2433526, 53.4805524],
#       [-2.2429915, 53.4805135],
#       [-2.2428105, 53.4804932],
#       [-2.2427374, 53.4804866],
#       [-2.2426982, 53.4806233],
#       [-2.242665, 53.4807429],
#       [-2.2426802, 53.4807595],
#       [-2.2430059, 53.4807939],
#       [-2.243226, 53.4808164],
#       [-2.2432803, 53.4808217],
#       [-2.2433556, 53.4805528]]]},
#    'properties': {'osid': '478961e4-67ae-486c-8829-524ef282f003',
#     'toid': 'osgb1000024085594',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 1272.67125,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-12',
#     'absoluteheightmaximum': 91.1,
#     'absoluteheightminimum': 43.04,
#     'geometry_evidencedate': '2010-04-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 48.06,
#     'absoluteheightroofbase': 84.3,
#     'description_updatedate': '2010-04-12',
#     'oslandcover_updatedate': '2010-04-12',
#     'oslanduse_evidencedate': '2010-04-12',
#     'relativeheightroofbase': 41.26,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-12',
#     'oslandcover_evidencedate': '2010-04-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '4b18285a-9273-4714-8789-fbe7081b3844',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2442994, 53.4802507],
#       [-2.2442903, 53.4802471],
#       [-2.2441505, 53.4801589],
#       [-2.244004, 53.4802459],
#       [-2.243935, 53.4802874],
#       [-2.2439305, 53.4802941],
#       [-2.243926, 53.4803004],
#       [-2.2439223, 53.4803081],
#       [-2.2439201, 53.4803153],
#       [-2.2439163, 53.4803256],
#       [-2.2439156, 53.4803364],
#       [-2.2439164, 53.4803391],
#       [-2.2439187, 53.4803476],
#       [-2.2439225, 53.4803557],
#       [-2.2439286, 53.4803656],
#       [-2.243937, 53.4803746],
#       [-2.2439415, 53.4803786],
#       [-2.2439521, 53.4803858],
#       [-2.2439627, 53.480392],
#       [-2.243977, 53.4803983],
#       [-2.2439921, 53.4804037],
#       [-2.2440065, 53.4804072],
#       [-2.2440215, 53.4804099],
#       [-2.2441015, 53.4804205],
#       [-2.2441188, 53.4804227],
#       [-2.2441628, 53.4803494],
#       [-2.2441763, 53.4803278],
#       [-2.2441778, 53.4803246],
#       [-2.2441808, 53.4803215],
#       [-2.2441853, 53.4803183],
#       [-2.2441898, 53.4803161],
#       [-2.2441935, 53.4803138],
#       [-2.2441973, 53.4803111],
#       [-2.2442994, 53.4802507]]]},
#    'properties': {'osid': '4b18285a-9273-4714-8789-fbe7081b3844',
#     'toid': 'osgb1000024085514',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 399.285,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2005-11-09',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2005-11-09',
#     'absoluteheightmaximum': 67.27,
#     'absoluteheightminimum': 40.77,
#     'geometry_evidencedate': '2005-11-09',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 26.5,
#     'absoluteheightroofbase': 53.42,
#     'description_updatedate': '2005-11-09',
#     'oslandcover_updatedate': '2005-11-09',
#     'oslanduse_evidencedate': '2005-11-09',
#     'relativeheightroofbase': 12.65,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2005-11-09',
#     'oslandcover_evidencedate': '2005-11-09',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '4b207c0d-c152-4fd7-9d8e-c53db3718196',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2389911, 53.478541],
#       [-2.2390512, 53.4785014],
#       [-2.2391375, 53.4784392],
#       [-2.2389969, 53.4783617],
#       [-2.238837, 53.4784577],
#       [-2.2389178, 53.4785016],
#       [-2.2389911, 53.478541]]]},
#    'properties': {'osid': '4b207c0d-c152-4fd7-9d8e-c53db3718196',
#     'toid': 'osgb1000024155699',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 199.81375,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 64.14,
#     'absoluteheightminimum': 43.08,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 21.06,
#     'absoluteheightroofbase': 61.23,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 18.15,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '4cdf6c54-7757-44dd-b202-d8ad7a595b1d',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2382579, 53.4768779],
#       [-2.2381385, 53.4768084],
#       [-2.2380867, 53.4768414],
#       [-2.2380694, 53.4768522],
#       [-2.2380536, 53.476863],
#       [-2.2380213, 53.4768828],
#       [-2.2381377, 53.4769523],
#       [-2.2382053, 53.4769094],
#       [-2.2382579, 53.4768779]]]},
#    'properties': {'osid': '4cdf6c54-7757-44dd-b202-d8ad7a595b1d',
#     'toid': 'osgb1000024155648',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 125.03375,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Retail',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-03-15',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-03-15',
#     'absoluteheightmaximum': 51.72,
#     'absoluteheightminimum': 41.23,
#     'geometry_evidencedate': '2010-03-15',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 10.49,
#     'absoluteheightroofbase': 49.55,
#     'description_updatedate': '2010-03-15',
#     'oslandcover_updatedate': '2010-03-15',
#     'oslanduse_evidencedate': '2010-03-15',
#     'relativeheightroofbase': 8.32,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-03-15',
#     'oslandcover_evidencedate': '2010-03-15',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}}]}

# %% [markdown]
# ### 4.2 Custom Paging Parameters
# By default, the `NGD` module will return a maximum 100 features - starting at zero. This behaviour can be altered by specifying `max_results` and `offset` parameters.
# *We'll build on the previous example, specifying the same extent as before...*

# %%
# returns a maximum of 50 results (features 0 to 50)
features = ngd_building_part.query(extent=extent, max_results=50)

# returns a maximum of 50 results (features 100 to 150
features = ngd_building_part.query(extent=extent, offset=100, max_results=50)

# 🔎 run this cell to see the contents of 'features'
features
# Out:
# {'type': 'FeatureCollection',
#  'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?offset=100&limit=50&filter=INTERSECTS%28geometry%2C%20POLYGON%20%28%28-2.237799%2053.47662%2C%20-2.237799%2053.480525%2C%20-2.244973%2053.480525%2C%20-2.244973%2053.47662%2C%20-2.237799%2053.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FOGC%2F1.3%2FCRS84',
#    'rel': 'self',
#    'type': 'application/geo+json',
#    'title': "All features from the 'Building Part' collection"},
#   {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?offset=50&limit=50&filter=INTERSECTS%28geometry%2C%20POLYGON%20%28%28-2.237799%2053.47662%2C%20-2.237799%2053.480525%2C%20-2.244973%2053.480525%2C%20-2.244973%2053.47662%2C%20-2.237799%2053.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FOGC%2F1.3%2FCRS84',
#    'rel': 'prev',
#    'type': 'application/geo+json',
#    'title': 'Previous page'},
#   {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?offset=150&limit=50&filter=INTERSECTS%28geometry%2C%20POLYGON%20%28%28-2.237799%2053.47662%2C%20-2.237799%2053.480525%2C%20-2.244973%2053.480525%2C%20-2.244973%2053.47662%2C%20-2.237799%2053.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FOGC%2F1.3%2FCRS84',
#    'rel': 'next',
#    'type': 'application/geo+json',
#    'title': 'Next page'}],
#  'timeStamp': '2022-11-08T12:44:27.434534Z',
#  'numberReturned': 50,
#  'features': [{'id': '4e1a5c52-aa3f-4c99-a216-f3ad0b5aff83',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.241327, 53.4780717],
#       [-2.2414253, 53.4780018],
#       [-2.2413543, 53.4779642],
#       [-2.2412545, 53.4780345],
#       [-2.241327, 53.4780717]]]},
#    'properties': {'osid': '4e1a5c52-aa3f-4c99-a216-f3ad0b5aff83',
#     'toid': 'osgb1000024155766',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 64.48625,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Retail',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 63.8,
#     'absoluteheightminimum': 41.84,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 21.96,
#     'absoluteheightroofbase': 62.62,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 20.78,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '50b0ab14-2a1a-41ae-8425-6ddafbddb575',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.

#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2390849, 53.4799539],
#       [-2.2390652, 53.4799679],
#       [-2.2391438, 53.4800071],
#       [-2.2391635, 53.4799931],
#       [-2.2390964, 53.4799596],
#       [-2.2390849, 53.4799539]]]},
#    'properties': {'osid': '576e3927-9673-4fd2-87cc-e18b84da1f3b',
#     'toid': 'osgb5000005289320947',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 13.841949,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2021-11-15',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2021-11-15',
#     'absoluteheightmaximum': 54.91,
#     'absoluteheightminimum': 45.07,
#     'geometry_evidencedate': '2021-04-19',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.84,
#     'absoluteheightroofbase': 54.63,
#     'description_updatedate': '2021-11-15',
#     'oslandcover_updatedate': '2021-11-15',
#     'oslanduse_evidencedate': '2021-04-19',
#     'relativeheightroofbase': 9.56,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2021-11-15',
#     'description_evidencedate': '2021-04-19',
#     'oslandcover_evidencedate': '2021-04-19',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '582f3a30-42a1-4ad2-9fd0-e9b97543c1d4',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2389581, 53.4785681],
#       [-2.2388327, 53.4785018],
#       [-2.2387949, 53.478483],
#       [-2.2387859, 53.4784794],
#       [-2.2387476, 53.478502],
#       [-2.2386072, 53.478589],
#       [-2.2387953, 53.478683],
#       [-2.2389551, 53.4785708],
#       [-2.2389581, 53.4785681]]]},
#    'properties': {'osid': '582f3a30-42a1-4ad2-9fd0-e9b97543c1d4',
#     'toid': 'osgb1000024157875',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 266.685,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-28',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-28',
#     'absoluteheightmaximum': 65.93,
#     'absoluteheightminimum': 43.43,
#     'geometry_evidencedate': '2010-04-28',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 22.5,
#     'absoluteheightroofbase': 58.8,
#     'description_updatedate': '2010-04-28',
#     'oslandcover_updatedate': '2010-04-28',
#     'oslanduse_evidencedate': '2010-04-28',
#     'relativeheightroofbase': 15.37,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-28',
#     'oslandcover_evidencedate': '2010-04-28',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '58d2d0a1-67a5-48f3-bf4d-4b7e576b08e5',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.244909, 53.4776159],
#       [-2.2451713, 53.4776496],
#       [-2.2451915, 53.4775937],
#       [-2.2449291, 53.47756],
#       [-2.244909, 53.4776159]]]},
#    'properties': {'osid': '58d2d0a1-67a5-48f3-bf4d-4b7e576b08e5',
#     'toid': 'osgb5000005154235949',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 113.2802,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Temporary Or Holiday Accommodation',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2015-05-21',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2015-05-21',
#     'absoluteheightmaximum': 72.44,
#     'absoluteheightminimum': 39.08,
#     'geometry_evidencedate': '2015-05-21',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 33.36,
#     'absoluteheightroofbase': 70.26,
#     'description_updatedate': '2015-05-21',
#     'oslandcover_updatedate': '2015-05-21',
#     'oslanduse_evidencedate': '2015-05-21',
#     'relativeheightroofbase': 31.18,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2015-05-21',
#     'description_evidencedate': '2015-05-21',
#     'oslandcover_evidencedate': '2015-05-21',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '58d67672-ea18-4a90-9306-f73461f5237c',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.243358, 53.4766374],
#       [-2.2432065, 53.4766866],
#       [-2.2431891, 53.4766923],
#       [-2.2432846, 53.4767968],
#       [-2.2434526, 53.4767421],
#       [-2.243358, 53.4766374]]]},
#    'properties': {'osid': '58d67672-ea18-4a90-9306-f73461f5237c',
#     'toid': 'osgb1000024084234',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 168.60505,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Retail',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1994-08-31',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1994-08-31',
#     'absoluteheightmaximum': 56.34,
#     'absoluteheightminimum': 37.68,
#     'geometry_evidencedate': '1994-08-31',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum':

#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-09-30',
#     'absoluteheightmaximum': 70.69,
#     'absoluteheightminimum': 45.3,
#     'geometry_evidencedate': '2010-09-30',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 25.39,
#     'absoluteheightroofbase': 68.13,
#     'description_updatedate': '2010-09-30',
#     'oslandcover_updatedate': '2010-09-30',
#     'oslanduse_evidencedate': '2010-09-30',
#     'relativeheightroofbase': 22.83,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2009-12-11',
#     'description_evidencedate': '2010-09-30',
#     'oslandcover_evidencedate': '2010-09-30',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '60e3c029-0d95-45c0-9a8d-3479b78fc96c',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2437135, 53.479762],
#       [-2.2437007, 53.4797692],
#       [-2.2437552, 53.4798145],
#       [-2.243809, 53.4798594],
#       [-2.2438435, 53.4798409],
#       [-2.2440012, 53.4797538],
#       [-2.2439816, 53.4797413],
#       [-2.2439211, 53.479705],
#       [-2.2438659, 53.4796727],
#       [-2.2437135, 53.479762]]]},
#    'properties': {'osid': '60e3c029-0d95-45c0-9a8d-3479b78fc96c',
#     'toid': 'osgb1000024085460',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 204.53,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-04-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-04-12',
#     'absoluteheightmaximum': 57.78,
#     'absoluteheightminimum': 41.15,
#     'geometry_evidencedate': '2010-04-12',
#     'heightconfidencelevel': 'Incomplete',
#     'relativeheightmaximum': 16.63,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '2010-04-12',
#     'oslandcover_updatedate': '2010-04-12',
#     'oslanduse_evidencedate': '2010-04-12',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-04-12',
#     'oslandcover_evidencedate': '2010-04-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '60ff576a-e0bd-4194-aa96-3b33e26e4de4',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2406686, 53.480374],
#       [-2.2406461, 53.4803893],
#       [-2.2406214, 53.4804064],
#       [-2.2405846, 53.4804316],
#       [-2.2405089, 53.4804835],
#       [-2.2405277, 53.4804929],
#       [-2.2405478, 53.4805029],
#       [-2.2406244, 53.4805412],
#       [-2.2406795, 53.4805692],
#       [-2.240703, 53.4805811],
#       [-2.2407377, 53.4805985],
#       [-2.2407763, 53.4806187],
#       [-2.2409354, 53.48051],
#       [-2.2406686, 53.480374]]]},
#    'properties': {'osid': '60ff576a-e0bd-4194-aa96-3b33e26e4de4',
#     'toid': 'osgb1000024158070',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 373.8545,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-05-20',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-05-20',
#     'absoluteheightmaximum': 87.85,
#     'absoluteheightminimum': 44.98,
#     'geometry_evidencedate': '2010-05-20',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 42.87,
#     'absoluteheightroofbase': 75.16,
#     'description_updatedate': '2010-05-20',
#     'oslandcover_updatedate': '2010-05-20',
#     'oslanduse_evidencedate': '2010-05-20',
#     'relativeheightroofbase': 30.18,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-05-20',
#     'oslandcover_evidencedate': '2010-05-20',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '61a23f1e-628b-4e68-84d6-f36414361fea',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2402511, 53.4779206],
#       [-2.2402957, 53.4779439],
#       [-2.2403444, 53.4779105],
#       [-2.2403747, 53.4779262],
#       [-2.2404655, 53.4778617],
#       [-2.2403937, 53.4778237],
#       [-2.2402511, 53.4779206]]]},
#    'properties': {'osid': '61a23f1e-628b-4e68-84d6-f36414361fea',
#     'toid': 'osgb1000024155718',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 80.1575,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 54.05,
#     'absoluteheightminimum': 42.08,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum':
#       [-2.2441933, 53.4790816],
#       [-2.2441797, 53.479078],
#       [-2.2441692, 53.4790758],
#       [-2.2441617, 53.4790866],
#       [-2.2441172, 53.4790745],
#       [-2.2441254, 53.4790637],
#       [-2.2441088, 53.4790597],
#       [-2.2441013, 53.4790701],
#       [-2.2440576, 53.4790585],
#       [-2.2440605, 53.4790531],
#       [-2.244047, 53.4790504],
#       [-2.2440395, 53.4790576],
#       [-2.2438306, 53.4790198]]]},
#    'properties': {'osid': '770a4332-78bf-48db-be50-92ae1ddfd3f4',
#     'toid': 'osgb1000024085450',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 704.97025,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Government Services',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2003-12-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2003-12-12',
#     'absoluteheightmaximum': 70.06,
#     'absoluteheightminimum': 40.2,
#     'geometry_evidencedate': '2003-12-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 29.86,
#     'absoluteheightroofbase': 57.49,
#     'description_updatedate': '2003-12-12',
#     'oslandcover_updatedate': '2003-12-12',
#     'oslanduse_evidencedate': '2003-12-12',
#     'relativeheightroofbase': 17.29,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2003-12-12',
#     'oslandcover_evidencedate': '2003-12-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '77efff23-7c77-4d66-82fb-70df3bdf9610',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2441188, 53.4804227],
#       [-2.2442131, 53.4804365],
#       [-2.2442489, 53.4803721],
#       [-2.2442744, 53.4803498],
#       [-2.2443206, 53.4803585],
#       [-2.2443719, 53.4802833],
#       [-2.2443024, 53.480252],
#       [-2.2442994, 53.4802507],
#       [-2.2441973, 53.4803111],
#       [-2.2441935, 53.4803138],
#       [-2.2441898, 53.4803161],
#       [-2.2441853, 53.4803183],
#       [-2.2441808, 53.4803215],
#       [-2.2441778, 53.4803246],
#       [-2.2441763, 53.4803278],
#       [-2.2441628, 53.4803494],
#       [-2.2441188, 53.4804227]]]},
#    'properties': {'osid': '77efff23-7c77-4d66-82fb-70df3bdf9610',
#     'toid': 'osgb1000024085515',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 153.144344,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Retail',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2014-07-22',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2005-11-18',
#     'absoluteheightmaximum': 58.11,
#     'absoluteheightminimum': 40.5,
#     'geometry_evidencedate': '2013-08-26',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 17.61,
#     'absoluteheightroofbase': 52.67,
#     'description_updatedate': '2005-11-18',
#     'oslandcover_updatedate': '2005-11-18',
#     'oslanduse_evidencedate': '2005-11-18',
#     'relativeheightroofbase': 12.17,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2005-11-18',
#     'oslandcover_evidencedate': '2005-11-18',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '789bdd8d-aa83-457f-8d5c-49c49e6cacd4',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2436647, 53.4771452],
#       [-2.2438293, 53.4770649],
#       [-2.2439307, 53.4770153],
#       [-2.2439855, 53.4769882],
#       [-2.2439417, 53.4769558],
#       [-2.2438873, 53.4769826],
#       [-2.2438929, 53.4769866],
#       [-2.2437914, 53.4770353],
#       [-2.2436239, 53.4771161],
#       [-2.2436647, 53.4771452]]]},
#    'properties': {'osid': '789bdd8d-aa83-457f-8d5c-49c49e6cacd4',
#     'toid': 'osgb1000024084240',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 116.70285,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-03-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-03-12',
#     'absoluteheightmaximum': 77.14,
#     'absoluteheightminimum': 37.21,
#     'geometry_evidencedate': '2010-03-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 39.93,
#     'absoluteheightroofbase': 74.13,
#     'description_updatedate': '2010-03-12',
#     'oslandcover_updatedate': '2010-03-12',
#     'oslanduse_evidencedate': '2010-03-12',
#     'relativeheightroofbase': 36.92,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1995-05-11',
#     'description_evidencedate': '2010-03-12',
#     'oslandcover_evidencedate': '2010-03-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '7a6f7cbb-8829-40d2-8b45-a58e3dfa5253',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2440432, 53.477198],
#       [-2.2441263, 53.4772382],
#       [-2.2441563, 53.4772166],
#       [-2.2440725, 53.4771759],
#       [-2.2440432, 53.477198]]]},
#    'properties': {'osid': '7a6f7cbb-8829-40d2-8b45-a58e3dfa5253',
#     'toid': 'osgb1000024084097',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 22.335,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 80.2,
#     'absoluteheightminimum': 39.74,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 40.46,
#     'absoluteheightroofbase': 47.96,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 8.22,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '7ba1fbd0-87cf-42de-abe1-27b41e1d0165',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2436194, 53.4771125],
#       [-2.2436156, 53.4771125],
#       [-2.2436111, 53.477113],
#       [-2.2436043, 53.4771139],
#       [-2.2435983, 53.4771144],
#       [-2.2435915, 53.4771144],
#       [-2.2435847, 53.4771139],
#       [-2.2435824, 53.477113],
#       [-2.2435764, 53.4771113],
#       [-2.2435719, 53.4771081],
#       [-2.2435448, 53.4771212],
#       [-2.2435638, 53.4771418],
#       [-2.2435729, 53.4771499],
#       [-2.2435789, 53.4771544],
#       [-2.2435857, 53.4771589],
#       [-2.2435903, 53.4771625],
#       [-2.2435955, 53.4771661],
#       [-2.2436024, 53.4771701],
#       [-2.2436092, 53.4771737],
#       [-2.2436379, 53.4771893],
#       [-2.2436679, 53.4771735],
#       [-2.2436672, 53.4771726],
#       [-2.2436634, 53.47717],
#       [-2.2436618, 53.4771668],
#       [-2.2436626, 53.4771637],
#       [-2.2436641, 53.4771605],
#       [-2.2436671, 53.4771551],
#       [-2.2436693, 53.4771529],
#       [-2.2436723, 53.4771502],
#       [-2.2436647, 53.4771452],
#       [-2.2436239, 53.4771161],
#       [-2.2436194, 53.4771125]]]},
#    'properties': {'osid': '7ba1fbd0-87cf-42de-abe1-27b41e1d0165',
#     'toid': 'osgb1000000254004331',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 40.8475,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2010-03-12',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-03-12',
#     'absoluteheightmaximum': 44.9,
#     'absoluteheightminimum': 39.01,
#     'geometry_evidencedate': '2010-03-12',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 5.89,
#     'absoluteheightroofbase': 42.99,
#     'description_updatedate': '2010-03-12',
#     'oslandcover_updatedate': '2010-03-12',
#     'oslanduse_evidencedate': '2010-03-12',
#     'relativeheightroofbase': 3.98,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-03-12',
#     'oslandcover_evidencedate': '2010-03-12',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '7c09e660-0c7d-475e-b973-c737ea3804bb',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2394019, 53.4795181],
#       [-2.2394109, 53.4795118],
#       [-2.2394342, 53.4794951],
#       [-2.2396473, 53.4793451],
#       [-2.2396935, 53.4793128],
#       [-2.2396345, 53.4792827],
#       [-2.239543, 53.4792361],
#       [-2.2395351, 53.4792321],
#       [-2.2394506, 53.4791891],
#       [-2.2394044, 53.4792213],
#       [-2.2393594, 53.4791984],
#       [-2.239353, 53.4792029],
#       [-2.2393791, 53.4792171],
#       [-2.2393649, 53.4792279],
#       [-2.2393754, 53.4792337],
#       [-2.2393244, 53.4792675],
#       [-2.2394347, 53.4793244],
#       [-2.239455, 53.4793108],
#       [-2.2395109, 53.4793395],
#       [-2.2394929, 53.4793526],
#       [-2.2395647, 53.4793897],
#       [-2.2394236, 53.4794893],
#       [-2.2392936, 53.4794226],
#       [-2.2392591, 53.4794478],
#       [-2.2394019, 53.4795181]]]},
#    'properties': {'osid': '7c09e660-0c7d-475e-b973-c737ea3804bb',
#     'toid': 'osgb1000024157955',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 311.881319,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2021-03-02',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2009-04-24',
#     'absoluteheightmaximum': 60.55,
#     'absoluteheightminimum': 43.07,
#     'geometry_evidencedate': '2020-08-30',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 17.48,
#     'absoluteheightroofbase': 44.01,
#     'description_updatedate': '2009-04-24',
#     'oslandcover_updatedate': '2009-04-24',
#     'oslanduse_evidencedate': '2009-04-24',
#     'relativeheightroofbase': 0.94,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2009-04-24',
#     'oslandcover_evidencedate': '2009-04-24',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '7c0d838d-1fbc-4696-95e7-25fa2f52bb44',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2435153, 53.4794332],
#       [-2.2435218, 53.479437],
#       [-2.2435505, 53.4794559],
#       [-2.2436352, 53.4795123],
#       [-2.2436962, 53.4795513],
#       [-2.2437118, 53.4795428],
#       [-2.2435309, 53.4794247],
#       [-2.2435153, 53.4794332]]]},
#    'properties': {'osid': '7c0d838d-1fbc-4696-95e7-25fa2f52bb44',
#     'toid': 'osgb1000002517038008',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 25.1958,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2007-03-20',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2007-03-20',
#     'absoluteheightmaximum': 60.18,
#     'absoluteheightminimum': 41.28,
#     'geometry_evidencedate': '2007-03-20',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 18.9,
#     'absoluteheightroofbase': 55.62,
#     'description_updatedate': '2007-03-20',
#     'oslandcover_updatedate': '2007-03-20',
#     'oslanduse_evidencedate': '2007-03-20',
#     'relativeheightroofbase': 14.34,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2007-03-20',
#     'description_evidencedate': '2007-03-20',
#     'oslandcover_evidencedate': '2007-03-20',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}}]}

# %% [markdown]
# ### 4.3 Applying CQL Filters
# Common Query Language (CQL) filters are a handy way in which you can tailor the results of your query to match specific needs. More information on CQL filters can be found [here](https://labs.os.uk/public/osngd/tutorials/articles/#filtering-and-cql). We can pass a filter into the API using the `filter` parameter.

# %%
# Building off the same extent covering Manchester, filtering by buildings larger than or equal to 20m^2 and with a maximum height greater than 60m.
# At the time of writing, this returns 7 features (buildings)
features = ngd_building_part.query(extent=extent, cql_filter='geometry_area>=200 AND relativeheightmaximum>60')

# 🔎 run this cell to see the contents of 'features'
features
# Out:
# {'type': 'FeatureCollection',
#  'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?limit=100&filter=geometry_area%3E%3D200%20AND%20relativeheightmaximum%3E60%20AND%20INTERSECTS%28geometry%2C%20POLYGON%20%28%28-2.237799%2053.47662%2C%20-2.237799%2053.480525%2C%20-2.244973%2053.480525%2C%20-2.244973%2053.47662%2C%20-2.237799%2053.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FOGC%2F1.3%2FCRS84',
#    'rel': 'self',
#    'type': 'application/geo+json',
#    'title': "All features from the 'Building Part' collection"}],
#  'timeStamp': '2022-11-08T12:44:30.285550Z',
#  'numberReturned': 7,
#  'features': [{'id': '40fa2462-4c01-48d4-bcf1-5179efb56027',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2428973, 53.4772335],
#       [-2.2428422, 53.477272],
#       [-2.2424657, 53.4775348],
#       [-2.2428301, 53.4777217],
#       [-2.2428936, 53.4777554],
#       [-2.2434293, 53.4773856],
#       [-2.2434177, 53.4773795],
#       [-2.2432818, 53.4772987],
#       [-2.2431787, 53.4772234],
#       [-2.2431397, 53.4771879],
#       [-2.2431367, 53.4771891],
#       [-2.2431108, 53.4771759],
#       [-2.243041, 53.4771403],
#       [-2.2430352, 53.4771373],
#       [-2.2430292, 53.4771414],
#       [-2.2428973, 53.4772335]]]},
#    'properties': {'osid': '40fa2462-4c01-48d4-bcf1-5179efb56027',
#     'toid': 'osgb5000005134737612',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 2122.693585,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2017-09-26',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2014-09-26',
#     'absoluteheightmaximum': 102.52,
#     'absoluteheightminimum': 38.65,
#     'geometry_evidencedate': '2017-09-26',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 63.87,
#     'absoluteheightroofbase': 94.76,
#     'description_updatedate': '2014-09-26',
#     'oslandcover_updatedate': '2014-09-26',
#     'oslanduse_evidencedate': '2013-11-04',
#     'relativeheightroofbase': 56.11,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2014-10-21',
#     'description_evidencedate': '2013-11-04',
#     'oslandcover_evidencedate': '2013-11-04',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '41ab80d3-28ca-460f-9afe-04671aa2807a',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2429831, 53.4804217],
#       [-2.2429958, 53.480423],
#       [-2.2429987, 53.4804133],
#       [-2.2430841, 53.4804225],
#       [-2.24313, 53.4803861],
#       [-2.2432185, 53.480316],
#       [-2.2432189, 53.4803155],
#       [-2.2432194, 53.4803152],
#       [-2.2432198, 53.4803147],
#       [-2.2432203, 53.4803143],
#       [-2.2432206, 53.4803138],
#       [-2.2432209, 53.4803133],
#       [-2.2432212, 53.4803128],
#       [-2.2432215, 53.4803124],
#       [-2.2432218, 53.4803118],
#       [-2.2432219, 53.4803114],
#       [-2.2432221, 53.4803108],
#       [-2.2432222, 53.4803103],
#       [-2.2432222, 53.4803099],
#       [-2.2432224, 53.4803093],
#       [-2.2432224, 53.4803088],
#       [-2.2432223, 53.4803082],
#       [-2.2432222, 53.4803077],
#       [-2.243222, 53.4803072],
#       [-2.2432219, 53.4803067],
#       [-2.2432217, 53.4803063],
#       [-2.2432216, 53.4803057],
#       [-2.2432213, 53.4803053],
#       [-2.243221, 53.4803047],
#       [-2.2432207, 53.4803043],
#       [-2.2432204, 53.4803038],
#       [-2.2432201, 53.4803034],
#       [-2.2432196, 53.4803029],
#       [-2.2432192, 53.4803025],
#       [-2.2432187, 53.480302],
#       [-2.2432181, 53.4803017],
#       [-2.2432173, 53.4803011],
#       [-2.2429327, 53.4800843],
#       [-2.2429318, 53.4800836],

#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2009-06-25',
#     'absoluteheightmaximum': 105.48,
#     'absoluteheightminimum': 43.2,
#     'geometry_evidencedate': '2009-06-25',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 62.28,
#     'absoluteheightroofbase': 100.7,
#     'description_updatedate': '2009-06-25',
#     'oslandcover_updatedate': '2009-06-25',
#     'oslanduse_evidencedate': '2009-06-25',
#     'relativeheightroofbase': 57.5,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2009-06-25',
#     'description_evidencedate': '2009-06-25',
#     'oslandcover_evidencedate': '2009-06-25',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '8a98fdc7-bc44-4ac0-8c20-aac5c7ddcf30',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.242827, 53.480133],
#       [-2.2427992, 53.4802216],
#       [-2.2427798, 53.4802852],
#       [-2.242751, 53.4803798],
#       [-2.242751, 53.4803806],
#       [-2.242751, 53.4803815],
#       [-2.2427511, 53.4803824],
#       [-2.2427513, 53.4803839],
#       [-2.2427514, 53.4803848],
#       [-2.2427521, 53.4803862],
#       [-2.2427524, 53.480387],
#       [-2.242753, 53.4803879],
#       [-2.2427534, 53.4803885],
#       [-2.2427539, 53.480389],
#       [-2.2427542, 53.4803895],
#       [-2.2427549, 53.4803909],
#       [-2.2427556, 53.4803918],
#       [-2.242756, 53.4803923],
#       [-2.2427565, 53.480393],
#       [-2.2427566, 53.4803931],
#       [-2.2427595, 53.4803958],
#       [-2.2427625, 53.4803985],
#       [-2.2427687, 53.4804034],
#       [-2.2427724, 53.4804058],
#       [-2.2427754, 53.4804072],
#       [-2.242777, 53.480408],
#       [-2.2427789, 53.4804087],
#       [-2.2427808, 53.4804094],
#       [-2.2427826, 53.4804101],
#       [-2.2427846, 53.4804107],
#       [-2.2427867, 53.4804111],
#       [-2.2427896, 53.4804119],
#       [-2.2429109, 53.4804249],
#       [-2.2429142, 53.4804143],
#       [-2.2427948, 53.4804015],
#       [-2.2427937, 53.4804012],
#       [-2.2427927, 53.480401],
#       [-2.2427916, 53.4804006],
#       [-2.2427907, 53.4804002],
#       [-2.2427897, 53.4803999],
#       [-2.2427887, 53.4803994],
#       [-2.2427878, 53.4803991],
#       [-2.2427869, 53.4803986],
#       [-2.242786, 53.4803981],
#       [-2.2427853, 53.4803977],
#       [-2.2427845, 53.4803971],
#       [-2.2427838, 53.4803966],
#       [-2.242783, 53.480396],
#       [-2.2427824, 53.4803955],
#       [-2.2427816, 53.4803948],
#       [-2.242781, 53.4803942],
#       [-2.2427806, 53.4803936],
#       [-2.24278, 53.480393],
#       [-2.2427795, 53.4803924],
#       [-2.2427792, 53.4803917],
#       [-2.2427788, 53.480391],
#       [-2.2427785, 53.4803904],
#       [-2.2427783, 53.4803897],
#       [-2.242778, 53.480389],
#       [-2.2427778, 53.4803883],
#       [-2.2427777, 53.4803877],
#       [-2.2427777, 53.4803869],
#       [-2.2427787, 53.4803836],
#       [-2.2428259, 53.4802245],
#       [-2.2428363, 53.4802257],
#       [-2.2428758, 53.480093],
#       [-2.2428765, 53.4800917],
#       [-2.2428786, 53.4800885],
#       [-2.2428802, 53.4800862],
#       [-2.2428822, 53.4800841],
#       [-2.2428834, 53.4800831],
#       [-2.2428844, 53.4800821],
#       [-2.2428856, 53.4800812],

#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 206.98995,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2009-06-25',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2009-06-25',
#     'absoluteheightmaximum': 104.38,
#     'absoluteheightminimum': 43.17,
#     'geometry_evidencedate': '2009-06-25',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 61.21,
#     'absoluteheightroofbase': 88.38,
#     'description_updatedate': '2009-06-25',
#     'oslandcover_updatedate': '2009-06-25',
#     'oslanduse_evidencedate': '2009-06-25',
#     'relativeheightroofbase': 45.21,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2009-06-25',
#     'description_evidencedate': '2009-06-25',
#     'oslandcover_evidencedate': '2009-06-25',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '8ce5ac53-d4ee-492d-9b6d-56b069252cbe',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2382779, 53.4780449],
#       [-2.2382231, 53.478081],
#       [-2.2381991, 53.4780963],
#       [-2.2379161, 53.4782811],
#       [-2.2380196, 53.4783371],
#       [-2.2380899, 53.4783752],
#       [-2.2381012, 53.4783814],
#       [-2.2382949, 53.4782547],
#       [-2.2383976, 53.4781874],
#       [-2.2384552, 53.4781497],
#       [-2.2385599, 53.4780812],
#       [-2.2384957, 53.4780463],
#       [-2.2384443, 53.4780185],
#       [-2.2383755, 53.4779809],
#       [-2.2382779, 53.4780449]]]},
#    'properties': {'osid': '8ce5ac53-d4ee-492d-9b6d-56b069252cbe',
#     'toid': 'osgb1000024155687',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-24',
#     'geometry_area': 748.799671,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2014-11-19',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2010-03-18',
#     'absoluteheightmaximum': 116.73,
#     'absoluteheightminimum': 43.13,
#     'geometry_evidencedate': '2013-11-04',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 73.6,
#     'absoluteheightroofbase': 109.57,
#     'description_updatedate': '2010-03-18',
#     'oslandcover_updatedate': '2010-03-18',
#     'oslanduse_evidencedate': '2010-03-18',
#     'relativeheightroofbase': 66.44,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '2010-03-18',
#     'oslandcover_evidencedate': '2010-03-18',
#     'versionavailablefromdate': '2022-09-25T00:00:00Z'}},
#   {'id': 'a1007205-9f06-4a36-bcba-45de245d9faf',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2428936, 53.4777554],
#       [-2.2429724, 53.4777971],
#       [-2.2435081, 53.4774273],
#       [-2.2434293, 53.4773856],
#       [-2.2428936, 53.4777554]]]},
#    'properties': {'osid': 'a1007205-9f06-4a36-bcba-45de245d9faf',
#     'toid': 'osgb5000005134737702',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 380.384512,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2014-10-13',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2014-10-13',
#     'absoluteheightmaximum': 99.96,
#     'absoluteheightminimum': 39.25,
#     'geometry_evidencedate': '2014-10-13',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 60.71,
#     'absoluteheightroofbase': 94.68,
#     'description_updatedate': '2014-10-13',
#     'oslandcover_updatedate': '2014-10-13',
#     'oslanduse_evidencedate': '2014-10-13',
#     'relativeheightroofbase': 55.43,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2014-10-21',
#     'description_evidencedate': '2014-10-13',
#     'oslandcover_evidencedate': '2014-10-13',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': 'af43ce9a-18d2-47d2-9744-fdc89f7c241c',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2422004, 53.4771864],
#       [-2.2421733, 53.477205],
#       [-2.2424868, 53.477362],
#       [-2.2430153, 53.4770021],
#       [-2.2430133, 53.477],
#       [-2.2427999, 53.4767749],
#       [-2.2422004, 53.4771864]]]},
#    'properties': {'osid': 'af43ce9a-18d2-47d2-9744-fdc89f7c241c',
#     'toid': 'osgb5000005267089134',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 1590.488141,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Commercial Activity: Industrial Or Manufacturing',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2020-07-16',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2020-07-16',
#     'absoluteheightmaximum': 102.53,
#     'absoluteheightminimum': 38.69,
#     'geometry_evidencedate': '2020-07-16',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 63.84,
#     'absoluteheightroofbase': 95.19,
#     'description_updatedate': '2020-07-16',
#     'oslandcover_updatedate': '2020-07-16',
#     'oslanduse_evidencedate': '2020-07-16',
#     'relativeheightroofbase': 56.5,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2020-07-16',
#     'description_evidencedate': '2020-07-16',
#     'oslandcover_evidencedate': '2020-07-16',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': 'cfe4934e-8360-40bb-81eb-5f49d240c2b8',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.2419265, 53.4779141],
#       [-2.242052, 53.4779799],
#       [-2.2421041, 53.4780072],
#       [-2.2421502, 53.4780309],
#       [-2.2422107, 53.4780627],
#       [-2.2422371, 53.4780748],
#       [-2.2426229, 53.4777933],
#       [-2.2426399, 53.4777809],
#       [-2.242627, 53.4777741],
#       [-2.2426099, 53.4777651],
#       [-2.2425899, 53.4777546],
#       [-2.2423386, 53.4776223],
#       [-2.2419265, 53.4779141]]]},
#    'properties': {'osid': 'cfe4934e-8360-40bb-81eb-5f49d240c2b8',
#     'toid': 'osgb5000005275364197',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 1143.781102,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Temporary Or Holiday Accommodation',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2021-01-13',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2021-01-13',
#     'absoluteheightmaximum': 112.0,
#     'absoluteheightminimum': 40.06,
#     'geometry_evidencedate': '2021-01-13',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 71.94,
#     'absoluteheightroofbase': 107.0,
#     'description_updatedate': '2021-01-13',
#     'oslandcover_updatedate': '2021-01-13',
#     'oslanduse_evidencedate': '2021-01-13',
#     'relativeheightroofbase': 66.94,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2021-01-13',
#     'description_evidencedate': '2021-01-13',
#     'oslandcover_evidencedate': '2021-01-13',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}}]}

# %% [markdown]
# ## 5. Conclusion
#
# We hope this short introduction to the `osdatahub` package's new NGD capabilities has been useful!
# You can find further resources to assist you on your OS API development journey at: [https://github.com/OrdnanceSurvey/os-api-resources](https://github.com/OrdnanceSurvey/os-api-resources)
