# %% [markdown]
# # Using the NGD API with Python
#
# The National Geographic Database (NGD) is Ordnance Survey's next generation API that makes it easier to use our data.
#
# There are many ways to access the NGD. If you'd like to download data using a GUI, OS has [Select+Build](https://www.ordnancesurvey.co.uk/business-government/products/os-select-build), an intuitive website that allows you to download multiple types of features at once. There is also a [REST API](https://www.ordnancesurvey.co.uk/business-government/products/os-ngd-api-features) for programatically access features by querying endpoints. If you are a JavaScript developer, we even created the [`osdatahub JavaScript library`](https://github.com/OrdnanceSurvey/osdatahub-js) that makes it easy to use NGD with Node.js or through the browser.
#
# For Python developers, we have the [`osdatahub Python library`](https://github.com/OrdnanceSurvey/osdatahub). The `osdatahub` package wraps almost all APIs in the [OS Data Hub](https://osdatahub.os.uk/) and provides an easy, Pythonic way to get data from Ordnance Survey. We have now added support for the NGD Features API, so you can access OS' newest product with only a few lines of Python code.
#
# This notebook takes us through using the NGD with the `osdatahub` Python library.

# %% [markdown]
# ## Setup
#
# In order to access the NGD, you  must first have an OS Data Hub api key. [This Python notebook](https://github.com/OrdnanceSurvey/osdatahub/blob/master/Examples/Setting%20up%20an%20API%20key.ipynb) takes you through registering an account and getting an API key. When you're choosing which APIs you want to add to your project, you must select "OS NGD API - Features".
#
# **Note:** The NGD API is a premium or public sector product only. If you are looking to access free data, you should use the [OS Features API](https://osdatahub.os.uk/docs/wfs/overview).
#
# Once you have an API key, you can load your API key by passing it in as a string, or setting it as an environment variable. We recommend using the [`python-dotenv`](https://pypi.org/project/python-dotenv/) library to securely store your API keys without risk of accidentally committing them in your repo.
#
# To use the `python-dotenv` package, simply:
# 1. Install with pip: `pip install python-dotenv`
# 2. Create a `.env` file in the root directory of your project
# 3. Add your API key to the file: `OS_API_KEY=[YOUR API KEY HERE]`

# %%
# setting api key as a string
key = "YOUR API KEY HERE"

# OR, using python-dotenv
from dotenv import load_dotenv
from os import environ

load_dotenv()

key = environ.get("OS_API_KEY")
key
# Out:
# 'jObazFUHCQgodV58uKS0fURLtTLS2inw'

# %% [markdown]
# ## Choosing a Collection
#
# The NGD can provide many types of feature, such as rail lines, roads, buildings, and waterways.
#
# To find the full list, you can either look at [the API's Technical Specification](https://osdatahub.os.uk/docs/ofa/technicalSpecification), or you can query using Python.
#
# We start by importing the NGD:

# %%
from osdatahub import NGD

# %% [markdown]
# A full, up-to-date list of available collections can be gotten through the `get_collections()` class method:

# %%
NGD.get_collections()
# Out:
# {'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections',
#    'rel': 'self',
#    'type': 'application/json',
#    'title': 'All collections'}],
#  'collections': [{'id': 'bld-fts-buildingline',
#    'title': 'Building Line',
#    'description': 'A feature which has a line geometry and represents a wall between two buildings, building internal divisions, or an overhanging building edge.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingline',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Building Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingline/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Building Line' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingline/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Building Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingline/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Building Line' feature collection"}]},
#   {'id': 'bld-fts-buildingpart',
#    'title': 'Building Part',
#    'description': 'Polygon feature representing either a complete separate building, or part of a larger building where internal divisions exist from ground to roof level which can be identified externally. Examples of Building Part features include a multistorey car park, a castle or a windmill.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Building Part' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Building Part' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Building Part' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Building Part' feature collection"}]},
#   {'id': 'gnm-fts-namedarea',
#    'title': 'Named Area',
#    'description': 'A settlement, locality, geographical feature, or area of water that has a name, represented as a polygon.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-07-30T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedarea',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Named Area' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedarea/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Named Area' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedarea/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Named Area' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedarea/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Named Area' feature collection"}]},
#   {'id': 'gnm-fts-namedpoint',
#    'title': 'Named Point',
#    'description': 'A settlement, locality, geographical feature, or area of water that has a name, represented as a point.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-07-30T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedpoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Named Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedpoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Named Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedpoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Named Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/gnm-fts-namedpoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Named Point' feature collection"}]},
#   {'id': 'lnd-fts-land',
#    'title': 'Land',
#    'description': "Polygon feature representing an area on the Earth's surface that has not otherwise been captured as a Building Part, Rail, Road Track Or Path, Structure, or Water Feature Type. Examples of Land features include arable or grazing land, made surface, bare earth or grass, and heath or rough grassland.",
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-land',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Land' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-land/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Land' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-land/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Land' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-land/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Land' feature collection"}]},
#   {'id': 'lnd-fts-landform',
#    'title': 'Landform',
#    'description': "Polygon feature representing an area of the Earth's surface with a distinct physical morphology, such as cliffs, artificial slopes, and burial mounds.",
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landform',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Landform' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landform/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Landform' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landform/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Landform' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landform/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Landform' feature collection"}]},
#   {'id': 'lnd-fts-landformline',
#    'title': 'Landform Line',
#    'description': 'Feature which has a line geometry and represents the alignment of either the higher limit, or the side or lower limit of areas with a distinct physical morphology, typically where there is a significant change in slope angle. This feature type is best used in combination with the Landform Feature Type.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformline',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Landform Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformline/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Landform Line' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformline/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Landform Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformline/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Landform Line' feature collection"}]},
#   {'id': 'lnd-fts-landformpoint',
#    'title': 'Landform Point',
#    'description': "Feature which has a point geometry and represents an area of the Earth's surface with a distinct physical morphology that is too small to capture as a Landform feature but is considered to be of sufficient interest to be captured, typically associated with former mineral workings.",
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformpoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Landform Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformpoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Landform Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformpoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Landform Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landformpoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Landform Point' feature collection"}]},
#   {'id': 'lnd-fts-landpoint',
#    'title': 'Land Point',
#    'description': "An area on the Earth's surface that has not otherwise been captured as a Building Part, Structure Point, or Water Point feature and is too small to capture as a Land feature, for example, a coniferous tree or a non-coniferous tree.",
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landpoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Land Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landpoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Land Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landpoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Land Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lnd-fts-landpoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Land Point' feature collection"}]},
#   {'id': 'lus-fts-site',
#    'title': 'Site',
#    'description': 'Polygon feature which represents the recognisable extent of certain types of function or activity. Examples include a caravan site, a university, and a railway centre.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-site',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Site' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-site/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Site' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-site/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Site' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-site/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Site' feature collection"}]},
#   {'id': 'lus-fts-siteaccesslocation',
#    'title': 'Site Access Location',
#    'description': 'Feature which has a point geometry and represents the locations where pedestrians and / or vehicles can enter or exit a site.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteaccesslocation',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Site Access Location' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteaccesslocation/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Site Access Location' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteaccesslocation/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Site Access Location' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteaccesslocation/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Site Access Location' feature collection"}]},
#   {'id': 'lus-fts-siteroutingpoint',
#    'title': 'Site Routing Point',
#    'description': 'The location on the road network which provides entry or exit into a site for vehicles and / or pedestrians, represented as a point geometry.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteroutingpoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Site Routing Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteroutingpoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Site Routing Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteroutingpoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Site Routing Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/lus-fts-siteroutingpoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Site Routing Point' feature collection"}]},
#   {'id': 'str-fts-compoundstructure',
#    'title': 'Compound Structure',
#    'description': 'Polygon feature which encompasses one or more components and represents a manmade construction that has been built for a specific purpose. Examples include a bridge, a dam, and an aqueduct.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-compoundstructure',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Compound Structure' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-compoundstructure/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Compound Structure' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-compoundstructure/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Compound Structure' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-compoundstructure/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Compound Structure' feature collection"}]},
#   {'id': 'str-fts-structure',
#    'title': 'Structure',
#    'description': 'Polygon feature representing a manmade construction that is not a building. Examples include a mast, a chimney, and a crane.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structure',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Structure' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structure/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Structure' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structure/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Structure' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structure/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Structure' feature collection"}]},
#   {'id': 'str-fts-structureline',
#    'title': 'Structure Line',
#    'description': 'Feature which has a line geometry and represents a linear, freestanding, manmade construction that is not a building and is not wide enough to capture as a structure. Examples include a gate or barrier, a pipeline, and a sea wall.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structureline',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Structure Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structureline/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Structure Line' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structureline/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Structure Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structureline/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Structure Line' feature collection"}]},
#   {'id': 'str-fts-structurepoint',
#    'title': 'Structure Point',
#    'description': 'Feature which has a point geometry and represents a freestanding manmade construction that is not a building and is less than 4m square but is considered to be of sufficient interest to be captured. Examples include a statue, a telephone call box, and a post box.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structurepoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Structure Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structurepoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Structure Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structurepoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Structure Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/str-fts-structurepoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Structure Point' feature collection"}]},
#   {'id': 'trn-fts-cartographicraildetail',
#    'title': 'Cartographic Rail Detail',
#    'description': 'A cartographic representation of a Railway Rail or Railway Buffer.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-cartographicraildetail',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Cartographic Rail Detail' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-cartographicraildetail/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Cartographic Rail Detail' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-cartographicraildetail/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Cartographic Rail Detail' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-cartographicraildetail/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Cartographic Rail Detail' feature collection"}]},
#   {'id': 'trn-fts-rail',
#    'title': 'Rail',
#    'description': 'Features related to travel by railway or tramway. Features representing, describing or limiting the extents of railways. The Transport Features Collection contains information relating to permanent railways that form the network between two points.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-rail',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Rail' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-rail/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Rail' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-rail/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Rail' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-rail/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Rail' feature collection"}]},
#   {'id': 'trn-fts-roadline',
#    'title': 'Road Line',
#    'description': 'A line feature representing the edges of traffic calming.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadline',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Road Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadline/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Road Line' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadline/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Road Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadline/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Road Line' feature collection"}]},
#   {'id': 'trn-fts-roadtrackorpath',
#    'title': 'Road Track Or Path',
#    'description': 'Features representing, describing or limiting the extents of roadways, tracks and pathways. A road is a metalled way for vehicles. A track is an unmetalled way that is clearly marked, permanent and used by vehicles. A path is defined as any established way other than a road or track.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-27T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadtrackorpath',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Road Track Or Path' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadtrackorpath/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Road Track Or Path' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadtrackorpath/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Road Track Or Path' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-fts-roadtrackorpath/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Road Track Or Path' feature collection"}]},
#   {'id': 'trn-ntwk-connectinglink',
#    'title': 'Connecting Link',
#    'description': 'The Road and Path Networks are not topologically structured together. Connecting Links have been introduced to enable a connection between the Road Network and the Path Network without splitting the Road Network. A Connecting Link feature is a linear spatial object which represents a logical connection between the Path Network and the Road Network, and they do represent a feature in the real world. A Connecting Link will always reference a Path Node and a Connecting Node.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/7405',
#     'http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/7405',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-23T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectinglink',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Connecting Link' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectinglink/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Connecting Link' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectinglink/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Connecting Link' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectinglink/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Connecting Link' feature collection"}]},
#   {'id': 'trn-ntwk-connectingnode',
#    'title': 'Connecting Node',
#    'description': 'A Connecting Node is a point feature that identifies the point along the Road Link which the Path Link connects to. The Connecting Node has been snapped to a vertex along the Road Link and provides a reference to the Road Link it has been snapped to. The Road Link is not split at the location of the Connecting Node. The Connecting Node is referenced by a Connecting Link.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/7405',
#     'http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/7405',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-23T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectingnode',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Connecting Node' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectingnode/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Connecting Node' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectingnode/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Connecting Node' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-connectingnode/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Connecting Node' feature collection"}]},
#   {'id': 'trn-ntwk-ferrylink',
#    'title': 'Ferry Link',
#    'description': 'A Ferry Link is a linear spatial object which represents the connectivity of a vehicular ferry route across a body of water. A Ferry Link will only be captured where both terminals are located within Great Britain and where there is a timetabled service which is available to the public. Ferry routes with a terminal located outside of Great Britain are not captured (for example, Dover to Calais) and neither are ferry routes where the service is not available to the public.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/7405',
#     'http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/7405',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-23T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrylink',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Ferry Link' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrylink/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Ferry Link' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrylink/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Ferry Link' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrylink/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Ferry Link' feature collection"}]},
#   {'id': 'trn-ntwk-ferrynode',
#    'title': 'Ferry Node',
#    'description': 'A Ferry Node is a point spatial object which is used to represent the connectivity where the Ferry Link features start and end. A Ferry Node feature may serve multiple Ferry Link features if more than one destination is served from the same location. Ferry Node’s will always be referenced by at least one Ferry Link.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/7405',
#     'http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/7405',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-23T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrynode',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Ferry Node' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrynode/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Ferry Node' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrynode/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Ferry Node' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferrynode/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Ferry Node' feature collection"}]},
#   {'id': 'trn-ntwk-ferryterminal',
#    'title': 'Ferry Terminal',
#    'description': 'The ferry and road network elements are linked together through a Ferry Terminal feature. A Ferry Terminal is a logical connection between the two networks and therefore there is no geometry supplied with these features. They will reference one Road Node and one Ferry Node. The Ferry Terminals will also provide a reference to the OS MasterMap Site feature.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-23T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferryterminal',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Ferry Terminal' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferryterminal/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Ferry Terminal' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferryterminal/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Ferry Terminal' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-ferryterminal/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Ferry Terminal' feature collection"}]},
#   {'id': 'trn-ntwk-path',
#    'title': 'Path',
#    'description': 'A Path feature is a link set which represents a collection of Path Link features that share the same name (for example, Church Walk). A Path will reference the complete collection of Road Link features irrespective of which authority boundary it falls within. A Path Link feature may be referenced by multiple Path features.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-08-23T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-path',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Path' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-path/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Path' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-path/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Path' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-ntwk-path/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
# ...
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-08T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationline',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Special Designation Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationline/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Special Designation Line' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationline/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Special Designation Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationline/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Special Designation Line' feature collection"}]},
#   {'id': 'trn-rami-specialdesignationpoint',
#    'title': 'Special Designation Point',
#    'description': 'Special Designations are statutory and advisory designations that can be applied to protect a highway when street or road works are to be undertaken. A Special Designation feature will reference back to the Roads product through Network Reference and will reference a Street Feature. Features which are a partial reference will provide a Network Reference Location.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-08T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationpoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Special Designation Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationpoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Special Designation Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationpoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Special Designation Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/trn-rami-specialdesignationpoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Special Designation Point' feature collection"}]},
#   {'id': 'wtr-fts-intertidalline',
#    'title': 'Inter Tidal Line',
#    'description': 'A watercourse that extends across the inter tidal zone.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-intertidalline',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Inter Tidal Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-intertidalline/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Inter Tidal Line' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-intertidalline/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Inter Tidal Line' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-intertidalline/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Inter Tidal Line' feature collection"}]},
#   {'id': 'wtr-fts-tidalboundary',
#    'title': 'Tidal Boundary',
#    'description': 'The alignment of the limit of tidal water at specific states of the tide.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-tidalboundary',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Tidal Boundary' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-tidalboundary/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Tidal Boundary' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-tidalboundary/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Tidal Boundary' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-tidalboundary/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Tidal Boundary' feature collection"}]},
#   {'id': 'wtr-fts-water',
#    'title': 'Water',
#    'description': 'Polygon feature representing an area of permanent inland water.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-water',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Water' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-water/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Water' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-water/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Water' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-water/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Water' feature collection"}]},
#   {'id': 'wtr-fts-waterpoint',
#    'title': 'Water Point',
#    'description': 'Point feature associated with permanent inland water that is too small to be captured as a Water feature but which OS consider to be of sufficient interest to be captured.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-17T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-waterpoint',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Water Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-waterpoint/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Water Point' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-waterpoint/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Water Point' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-fts-waterpoint/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Water Point' feature collection"}]},
#   {'id': 'wtr-ntwk-waterlink',
#    'title': 'Water Link',
#    'description': 'A network representation of the general alignment and connectivity of permanent water, including rivers, lakes, and canals.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/7405',
#     'http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/7405',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-03T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Water Link' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Water Link' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Water Link' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlink/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Water Link' feature collection"}]},
#   {'id': 'wtr-ntwk-waterlinkset',
#    'title': 'Water Link Set',
#    'description': 'A body of water with an accepted name that the water network flows through.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/27700',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-03T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlinkset',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Water Link Set' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlinkset/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Water Link Set' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlinkset/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Water Link Set' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waterlinkset/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Water Link Set' feature collection"}]},
#   {'id': 'wtr-ntwk-waternode',
#    'title': 'Water Node',
#    'description': 'The location where a connected area of permanent water ends, where an area of permanent water is connected to two or more other areas of permanent water, or where a recorded attribute changes for an area of permanent water.',
#    'crs': ['http://www.opengis.net/def/crs/EPSG/0/7405',
#     'http://www.opengis.net/def/crs/EPSG/0/27700',
#     'http://www.opengis.net/def/crs/EPSG/0/3857',
#     'http://www.opengis.net/def/crs/EPSG/0/4326',
#     'http://www.opengis.net/def/crs/OGC/1.3/CRS84'],
#    'storageCrs': 'http://www.opengis.net/def/crs/EPSG/0/7405',
#    'itemType': 'feature',
#    'extent': {'spatial': {'bbox': [[-8.82, 49.79, 1.92, 60.94]],
#      'crs': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84'},
#     'temporal': {'interval': [['2022-09-03T00:00:00Z', None]],
#      'trs': 'http://www.opengis.net/def/uom/ISO-8601/0/Gregorian'}},
#    'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waternode',
#      'rel': 'self',
#      'type': 'application/json',
#      'title': "The 'Water Node' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waternode/items',
#      'rel': 'items',
#      'type': 'application/geo+json',
#      'title': "The features in the 'Water Node' feature collection as GeoJSON"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waternode/schema',
#      'rel': 'describedby',
#      'type': 'application/schema+json',
#      'title': "Schema for the 'Water Node' feature collection"},
#     {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/wtr-ntwk-waternode/queryables',
#      'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#      'type': 'application/schema+json',
#      'title': "The queryable attributes for the 'Water Node' feature collection"}]}]}

# %% [markdown]
# After looking at the available collections, we'll be using the Building Part feature. The NGD API uses the id for a given collection, which in our case is `bld-fts-buildingpart`. You can find out more about how the ids are created by reading the Content section of the [Technical Specification](https://osdatahub.os.uk/docs/ofa/technicalSpecification)

# %% [markdown]
# ## Getting your First Features
#
# Now that we have our API key and the id of the collection we'd like to get, we are ready to go! To get the first 100 features in the collection, you simply need to make an `NGD` object and then run the `query()` method:

# %%
collection = "bld-fts-buildingpart"

ngd = NGD(key, collection)
features = ngd.query()
features
# Out:
# {'type': 'FeatureCollection',
#  'links': [{'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?limit=100',
#    'rel': 'self',
#    'type': 'application/geo+json',
#    'title': "All features from the 'Building Part' collection"},
#   {'href': 'https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items?offset=100&limit=100',
#    'rel': 'next',
#    'type': 'application/geo+json',
#    'title': 'Next page'}],
#  'timeStamp': '2022-11-04T12:03:43.220253Z',
#  'numberReturned': 100,
#  'features': [{'id': '000000b1-0556-4231-a52a-9b5b8b82dfbf',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-3.9703075, 55.7425473],
#       [-3.9701862, 55.7424916],
#       [-3.9701342, 55.7425277],
#       [-3.9702899, 55.7425992],
#       [-3.9703201, 55.7425783],
#       [-3.9702857, 55.7425625],
#       [-3.9703075, 55.7425473]]]},
#    'properties': {'osid': '000000b1-0556-4231-a52a-9b5b8b82dfbf',
#     'toid': 'osgb1000041024621',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-18',
#     'geometry_area': 59.20065,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2006-08-30',
#     'height_evidencedate': '2022-06-20',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2006-08-30',
#     'absoluteheightmaximum': 115.16,
#     'absoluteheightminimum': 105.0,
#     'geometry_evidencedate': '2006-08-30',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 10.16,
#     'absoluteheightroofbase': 110.85,
#     'description_updatedate': '2006-08-30',
#     'oslandcover_updatedate': '2006-08-30',
#     'oslanduse_evidencedate': '2006-08-30',
#     'relativeheightroofbase': 5.85,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1991-09-18',
#     'description_evidencedate': '2006-08-30',
#     'oslandcover_evidencedate': '2006-08-30',
#     'versionavailablefromdate': '2022-09-19T00:00:00Z'}},
#   {'id': '00000183-3ae0-4f05-adb8-a5792d09f55f',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[1.7275593, 52.6614194],
#       [1.7275547, 52.6614375],
#       [1.7274869, 52.6614311],
#       [1.7274915, 52.661413],
#       [1.7275593, 52.6614194]]]},
#    'properties': {'osid': '00000183-3ae0-4f05-adb8-a5792d09f55f',
#     'toid': 'osgb5000005167584940',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 9.499142,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2015-10-29',
#     'height_evidencedate': '2022-04-16',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2015-10-29',
#     'absoluteheightmaximum': 7.29,
#     'absoluteheightminimum': 5.39,
#     'geometry_evidencedate': '2015-03-11',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 1.9,
#     'absoluteheightroofbase': 6.21,
#     'description_updatedate': '2015-10-29',
#     'oslandcover_updatedate': '2015-10-29',
#     'oslanduse_evidencedate': '2015-03-11',
#     'relativeheightroofbase': 0.82,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2015-11-12',
#     'description_evidencedate': '2015-03-11',
#     'oslandcover_evidencedate': '2015-03-11',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000001d6-8217-4f7a-a70e-3757eb76c9e4',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[0.1941514, 51.5924144],
#       [0.194112, 51.5924057],
#       [0.194138, 51.5923612],
#       [0.1941775, 51.5923703],
#       [0.1941514, 51.5924144]]]},
#    'properties': {'osid': '000001d6-8217-4f7a-a70e-3757eb76c9e4',
#     'toid': 'osgb1000000360448',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 15.25875,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-04-01',
#     'height_evidencedate': '2022-07-10',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-04-01',
#     'absoluteheightmaximum': 38.63,
#     'absoluteheightminimum': 34.7,
#     'geometry_evidencedate': '1993-04-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 3.93,
#     'absoluteheightroofbase': 37.13,
#     'description_updatedate': '1993-04-01',
#     'oslandcover_updatedate': '1993-04-01',
#     'oslanduse_evidencedate': '1993-04-01',
#     'relativeheightroofbase': 2.43,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-04-01',
#     'description_evidencedate': '1993-04-01',
#     'oslandcover_evidencedate': '1993-04-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000208-a659-49f9-a587-ab26cb2b2248',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.454721, 52.3961029],
#       [-1.4547862, 52.3961253],
#       [-1.454804, 52.3961051],
#       [-1.4547382, 52.3960832],
#       [-1.454721, 52.3961029]]]},
#    'properties': {'osid': '00000208-a659-49f9-a587-ab26cb2b2248',
#     'toid': 'osgb1000017249389',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 12.80625,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-05-01',
#     'height_evidencedate': '2022-02-27',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-05-01',
#     'absoluteheightmaximum': 72.8,
#     'absoluteheightminimum': 69.99,
#     'geometry_evidencedate': '1993-05-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 2.81,
#     'absoluteheightroofbase': 71.95,
#     'description_updatedate': '1993-05-01',
#     'oslandcover_updatedate': '1993-05-01',
#     'oslanduse_evidencedate': '1993-05-01',
#     'relativeheightroofbase': 1.96,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-05-01',
#     'description_evidencedate': '1993-05-01',
#     'oslandcover_evidencedate': '1993-05-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000246-42c8-4e23-982e-15613e0fd2fe',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[0.9389847, 52.8177154],
#       [0.9389963, 52.8176695],
#       [0.9391636, 52.8176851],
#       [0.9391521, 52.8177303],
#       [0.9391389, 52.8177291],
#       [0.939087, 52.8177242],
#       [0.9389847, 52.8177154]]]},
#    'properties': {'osid': '00000246-42c8-4e23-982e-15613e0fd2fe',
#     'toid': 'osgb1000008341371',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 58.280086,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2020-01-03',
#     'height_evidencedate': '2021-04-23',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2005-04-30',
#     'absoluteheightmaximum': 58.41,
#     'absoluteheightminimum': 50.85,
#     'geometry_evidencedate': '2019-05-15',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 7.56,
#     'absoluteheightroofbase': 54.46,
#     'description_updatedate': '2005-04-30',
#     'oslandcover_updatedate': '2005-04-30',
#     'oslanduse_evidencedate': '2005-04-30',
#     'relativeheightroofbase': 3.61,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1992-03-13',
#     'description_evidencedate': '2005-04-30',
#     'oslandcover_evidencedate': '2005-04-30',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000267-0599-4afe-b46b-bbc0b3ccddd7',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.4127509, 53.3487227],
#       [-1.412756, 53.3487897],
#       [-1.412756, 53.3487915],
#       [-1.4127575, 53.3488166],
#       [-1.4128215, 53.3488148],
#       [-1.4128194, 53.3487879],
#       [-1.4128387, 53.3487874],
#       [-1.4128343, 53.3487204],
#       [-1.4127509, 53.3487227]]]},
#    'properties': {'osid': '00000267-0599-4afe-b46b-bbc0b3ccddd7',
#     'toid': 'osgb1000026269447',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 53.989401,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2016-06-02',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-04-01',
#     'absoluteheightmaximum': 163.94,
#     'absoluteheightminimum': 154.5,
#     'geometry_evidencedate': '2015-07-03',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.44,
#     'absoluteheightroofbase': 160.8,
#     'description_updatedate': '1993-04-01',
#     'oslandcover_updatedate': '1993-04-01',
#     'oslanduse_evidencedate': '1993-04-01',
#     'relativeheightroofbase': 6.3,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-04-01',
#     'description_evidencedate': '1993-04-01',
#     'oslandcover_evidencedate': '1993-04-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000002ab-4146-459d-a089-32bc7e78487f',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-0.1964699, 51.4923347],
#       [-0.1964589, 51.4923394],
#       [-0.1965008, 51.4923738],
#       [-0.1965118, 51.4923686],
#       [-0.1964699, 51.4923347]]]},
#    'properties': {'osid': '000002ab-4146-459d-a089-32bc7e78487f',
#     'toid': 'osgb1000004181604',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 4.51875,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1986-10-16',
#     'height_evidencedate': None,
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1986-10-16',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '1986-10-16',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '1986-10-16',
#     'oslandcover_updatedate': '1986-10-16',
#     'oslanduse_evidencedate': '1986-10-16',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1986-10-16',
#     'description_evidencedate': '1986-10-16',
#     'oslandcover_evidencedate': '1986-10-16',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000002bb-92f6-407c-8563-a571dc1d4c43',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.3093918, 56.9145765],
#       [-2.3093868, 56.9145572],
#       [-2.3090601, 56.9145823],
#       [-2.3091331, 56.9148633],
#       [-2.3094546, 56.9148386],
#       [-2.3094597, 56.9148382],
#       [-2.3094271, 56.9147125],
#       [-2.3093918, 56.9145765]]]},
#    'properties': {'osid': '000002bb-92f6-407c-8563-a571dc1d4c43',
#     'toid': 'osgb1000039732895',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-26',
#     'geometry_area': 634.53085,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2022-09-02',
#     'height_evidencedate': None,
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2010-12-17',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '2022-06-04',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '2010-12-17',
#     'oslandcover_updatedate': '2010-12-17',
#     'oslanduse_evidencedate': '2010-12-17',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-08-25',
#     'description_evidencedate': '2010-12-17',
#     'oslandcover_evidencedate': '2010-12-17',
#     'versionavailablefromdate': '2022-09-27T00:00:00Z'}},
#   {'id': '00000357-5160-4752-b7f9-e41793e5716f',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[0.1139358, 51.5352425],
#       [0.1140106, 51.5352729],
#       [0.1139713, 51.5353105],
#       [0.1139126, 51.5353665],
#       [0.1138391, 51.5353363],
#       [0.1138971, 51.5352804],
#       [0.1139358, 51.5352425]]]},
#    'properties': {'osid': '00000357-5160-4752-b7f9-e41793e5716f',
#     'toid': 'osgb1000007459665',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-18',
#     'geometry_area': 76.312258,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2017-11-03',
#     'height_evidencedate': '2021-04-18',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1970-01-01',
#     'absoluteheightmaximum': 15.59,
#     'absoluteheightminimum': 6.74,
#     'geometry_evidencedate': '2016-08-24',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 8.85,
#     'absoluteheightroofbase': 10.98,
#     'description_updatedate': '1970-01-01',
#     'oslandcover_updatedate': '1970-01-01',
#     'oslanduse_evidencedate': '1970-01-01',
#     'relativeheightroofbase': 4.24,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '1970-01-01',
#     'oslandcover_evidencedate': '1970-01-01',
#     'versionavailablefromdate': '2022-09-19T00:00:00Z'}},
#   {'id': '000003c3-0a97-4937-ac47-cb0dd691a806',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[0.0808045, 51.3707358],
#       [0.0807515, 51.3707665],
#       [0.0807014, 51.3707327],
#       [0.0806601, 51.3707567],
#       [0.080621, 51.3707304],
#       [0.0806624, 51.3707064],
#       [0.0807554, 51.3706526],
#       [0.0807739, 51.3706644],
#       [0.0807879, 51.370656],
#       [0.0808346, 51.3706862],
#       [0.0808317, 51.3706876],
#       [0.0808577, 51.3707052],
#       [0.0808045, 51.3707358]]]},
#    'properties': {'osid': '000003c3-0a97-4937-ac47-cb0dd691a806',
#     'toid': 'osgb1000007156988',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 106.163066,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2017-11-04',
#     'height_evidencedate': '2021-04-17',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-03-01',
#     'absoluteheightmaximum': 118.84,
#     'absoluteheightminimum': 111.47,
#     'geometry_evidencedate': '2016-09-15',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 7.37,
#     'absoluteheightroofbase': 115.94,
#     'description_updatedate': '1993-03-01',
#     'oslandcover_updatedate': '1993-03-01',
#     'oslanduse_evidencedate': '1993-03-01',
#     'relativeheightroofbase': 4.47,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-03-01',
#     'description_evidencedate': '1993-03-01',
#     'oslandcover_evidencedate': '1993-03-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000454-e43b-4fba-a17d-2fc09d6f4073',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.6983604, 51.4803887],
#       [-2.6983397, 51.4804024],
#       [-2.6983899, 51.4804319],
#       [-2.698411, 51.4804188],
#       [-2.6984224, 51.4804256],
#       [-2.6985661, 51.4803316],
#       [-2.6985538, 51.4803242],
#       [-2.6985776, 51.4803087],
#       [-2.6985391, 51.4802857],
#       [-2.698514, 51.4803021],
#       [-2.698503, 51.4802956],
#       [-2.6984394, 51.4803371],
#       [-2.6983604, 51.4803887]]]},
#    'properties': {'osid': '00000454-e43b-4fba-a17d-2fc09d6f4073',
#     'toid': 'osgb1000027912285',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 104.75451,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2020-01-21',
#     'height_evidencedate': '2022-06-15',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2001-12-11',
#     'absoluteheightmaximum': 19.51,
#     'absoluteheightminimum': 15.59,
#     'geometry_evidencedate': '2019-08-24',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 3.92,
#     'absoluteheightroofbase': 17.48,
#     'description_updatedate': '2001-12-11',
#     'oslandcover_updatedate': '2001-12-11',
#     'oslanduse_evidencedate': '2001-12-11',
#     'relativeheightroofbase': 1.89,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1990-03-01',
#     'description_evidencedate': '2001-12-11',
#     'oslandcover_evidencedate': '2001-12-11',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000480-88f7-471a-837e-6fcbd5ceb2cd',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.9565595, 50.8704568],
#       [-2.9564861, 50.8704598],
#       [-2.9564924, 50.8705238],
#       [-2.9565658, 50.8705208],
#       [-2.9565595, 50.8704568]]]},
#    'properties': {'osid': '00000480-88f7-471a-837e-6fcbd5ceb2cd',
#     'toid': 'osgb1000027578815',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-18',
#     'geometry_area': 36.9014,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2004-06-04',
#     'height_evidencedate': '2022-04-16',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2004-06-04',
#     'absoluteheightmaximum': 105.62,
#     'absoluteheightminimum': 97.81,
#     'geometry_evidencedate': '2004-06-04',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 7.81,
#     'absoluteheightroofbase': 104.86,
#     'description_updatedate': '2004-06-04',
#     'oslandcover_updatedate': '2004-06-04',
#     'oslanduse_evidencedate': '2004-06-04',
#     'relativeheightroofbase': 7.05,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '2004-06-04',
#     'oslandcover_evidencedate': '2004-06-04',
#     'versionavailablefromdate': '2022-09-19T00:00:00Z'}},
#   {'id': '0000054e-b3bb-4213-a3b1-b59c3083e278',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.0864428, 51.8930438],
#       [-2.0864269, 51.8929952],
#       [-2.086355, 51.8930041],
#       [-2.0863099, 51.8930097],
#       [-2.0863194, 51.8930394],
#       [-2.0862882, 51.8930434],
#       [-2.0862941, 51.893062],
#       [-2.0864428, 51.8930438]]]},
#    'properties': {'osid': '0000054e-b3bb-4213-a3b1-b59c3083e278',
#     'toid': 'osgb1000019505314',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 49.84775,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2018-01-31',
#     'height_evidencedate': '2022-07-18',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1994-09-27',
#     'absoluteheightmaximum': 73.96,
#     'absoluteheightminimum': 66.8,
#     'geometry_evidencedate': '2015-07-03',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 7.16,
#     'absoluteheightroofbase': 71.32,
#     'description_updatedate': '1994-09-27',
#     'oslandcover_updatedate': '1994-09-27',
#     'oslanduse_evidencedate': '1994-09-27',
#     'relativeheightroofbase': 4.52,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1994-09-27',
#     'description_evidencedate': '1994-09-27',
#     'oslandcover_evidencedate': '1994-09-27',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0000056d-3d98-4cd8-8480-47001df282e9',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[0.4386024, 51.5764476],
#       [0.4386858, 51.5764558],
#       [0.4386679, 51.5765254],
#       [0.4385482, 51.5765139],
#       [0.4385607, 51.5764647],
#       [0.4385977, 51.5764684],
#       [0.4386024, 51.5764476]]]},
#    'properties': {'osid': '0000056d-3d98-4cd8-8480-47001df282e9',
#     'toid': 'osgb1000001015512',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 60.03,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2007-10-17',
#     'height_evidencedate': '2022-07-10',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2007-10-17',
#     'absoluteheightmaximum': 37.31,
#     'absoluteheightminimum': 30.44,
#     'geometry_evidencedate': '2007-10-17',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 6.87,
#     'absoluteheightroofbase': 33.26,
#     'description_updatedate': '2007-10-17',
#     'oslandcover_updatedate': '2007-10-17',
#     'oslanduse_evidencedate': '2007-10-17',
#     'relativeheightroofbase': 2.82,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1990-02-20',
#     'description_evidencedate': '2007-10-17',
#     'oslandcover_evidencedate': '2007-10-17',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000583-5923-48c3-82b9-d3aa12abca35',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.4425405, 53.7470504],
#       [-2.4424254, 53.7471377],
#       [-2.4424826, 53.7471649],
#       [-2.4425706, 53.747099],
#       [-2.4425485, 53.7470887],
#       [-2.4425763, 53.7470675],
#       [-2.4425557, 53.7470577],
#       [-2.4425405, 53.7470504]]]},
#    'properties': {'osid': '00000583-5923-48c3-82b9-d3aa12abca35',
#     'toid': 'osgb1000028714830',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-18',
#     'geometry_area': 54.454875,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2018-07-11',
#     'height_evidencedate': '2020-04-24',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1970-01-01',
#     'absoluteheightmaximum': 161.52,
#     'absoluteheightminimum': 152.1,
#     'geometry_evidencedate': '2018-05-07',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.42,
#     'absoluteheightroofbase': 158.24,
#     'description_updatedate': '1970-01-01',
#     'oslandcover_updatedate': '1970-01-01',
#     'oslanduse_evidencedate': '1970-01-01',
#     'relativeheightroofbase': 6.14,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '1970-01-01',
#     'oslandcover_evidencedate': '1970-01-01',
#     'versionavailablefromdate': '2022-09-19T00:00:00Z'}},
#   {'id': '00000599-2747-4a90-9e57-1e62b746d510',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-5.063328, 50.2675958],
#       [-5.063409, 50.2676009],
#       [-5.06342, 50.2675296],
#       [-5.0633391, 50.2675245],
#       [-5.063328, 50.2675958]]]},
#    'properties': {'osid': '00000599-2747-4a90-9e57-1e62b746d510',
#     'toid': 'osgb1000011522444',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 46.25435,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1989-12-07',
#     'height_evidencedate': '2021-06-01',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1989-12-07',
#     'absoluteheightmaximum': 34.46,
#     'absoluteheightminimum': 26.97,
#     'geometry_evidencedate': '1989-12-07',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 7.49,
#     'absoluteheightroofbase': 32.13,
#     'description_updatedate': '1989-12-07',
#     'oslandcover_updatedate': '1989-12-07',
#     'oslanduse_evidencedate': '1989-12-07',
#     'relativeheightroofbase': 5.16,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1989-12-07',
#     'description_evidencedate': '1989-12-07',
#     'oslandcover_evidencedate': '1989-12-07',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0000059d-0207-4ee9-8ef3-396af0748a08',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.1314447, 50.7819735],
#       [-1.131474, 50.7820025],
#       [-1.1315109, 50.7820378],
#       [-1.1315824, 50.7820082],
#       [-1.1315162, 50.7819434],
#       [-1.1315047, 50.7819483],
#       [-1.1314447, 50.7819735]]]},
#    'properties': {'osid': '0000059d-0207-4ee9-8ef3-396af0748a08',
#     'toid': 'osgb1000013104617',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 51.80065,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2013-05-24',
#     'height_evidencedate': '2021-04-17',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1980-07-25',
#     'absoluteheightmaximum': 10.09,
#     'absoluteheightminimum': 4.32,
#     'geometry_evidencedate': '2012-07-23',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 5.77,
#     'absoluteheightroofbase': 9.46,
#     'description_updatedate': '1980-07-25',
#     'oslandcover_updatedate': '1980-07-25',
#     'oslanduse_evidencedate': '1980-07-25',
#     'relativeheightroofbase': 5.14,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1980-07-25',
#     'description_evidencedate': '1980-07-25',
#     'oslandcover_evidencedate': '1980-07-25',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000005dc-13b9-42f6-aa52-31f74ea026b6',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[1.2672883, 52.4572748],
#       [1.2672956, 52.4572885],
#       [1.2672753, 52.4572912],
#       [1.2672707, 52.4572768],
#       [1.2672883, 52.4572748]]]},
#    'properties': {'osid': '000005dc-13b9-42f6-aa52-31f74ea026b6',
#     'toid': 'osgb1000007822530',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 2.1131,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2003-03-25',
#     'height_evidencedate': None,
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2003-03-25',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '2003-03-25',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '2003-03-25',
#     'oslandcover_updatedate': '2003-03-25',
#     'oslanduse_evidencedate': '2003-03-25',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1992-09-07',
#     'description_evidencedate': '2003-03-25',
#     'oslandcover_evidencedate': '2003-03-25',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000623-0781-408b-88bf-46884f0c2248',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-0.1006267, 51.2915096],
#       [-0.1006327, 51.2915183],
#       [-0.1006327, 51.2915184],
#       [-0.1006106, 51.2915244],
#       [-0.1006492, 51.2915803],
#       [-0.1007645, 51.2915494],
#       [-0.1007252, 51.2914934],
#       [-0.1006842, 51.2915045],
#       [-0.1006781, 51.2914957],
#       [-0.100651, 51.291503],
#       [-0.1006267, 51.2915096]]]},
#    'properties': {'osid': '00000623-0781-408b-88bf-46884f0c2248',
#     'toid': 'osgb1000005820817',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 63.411911,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2017-10-03',
#     'height_evidencedate': '2022-04-17',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1970-01-01',
#     'absoluteheightmaximum': 183.37,
#     'absoluteheightminimum': 175.31,
#     'geometry_evidencedate': '2016-09-16',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 8.06,
#     'absoluteheightroofbase': 178.07,
#     'description_updatedate': '1970-01-01',
#     'oslandcover_updatedate': '1970-01-01',
#     'oslanduse_evidencedate': '1970-01-01',
#     'relativeheightroofbase': 2.76,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '1970-01-01',
#     'oslandcover_evidencedate': '1970-01-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00000695-c09f-4cc4-bfd5-4ee9084cf67d',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.8523263, 53.4149608],
#       [-2.8523283, 53.4149633],
#       [-2.8523331, 53.4149693],
#       [-2.8524301, 53.4149415],
#       [-2.852424, 53.4149337],
#       [-2.8523263, 53.4149608]]]},
#    'properties': {'osid': '00000695-c09f-4cc4-bfd5-4ee9084cf67d',
#     'toid': 'osgb1000035422968',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 7.17599,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2017-01-05',
#     'height_evidencedate': None,
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1970-01-01',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '2016-05-12',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '1970-01-01',
#     'oslandcover_updatedate': '1970-01-01',
#     'oslanduse_evidencedate': '1970-01-01',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '1970-01-01',
#     'oslandcover_evidencedate': '1970-01-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '0000088b-0635-46d6-9ce8-4d61de6eef11',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-3.1791366, 51.4444384],
#       [-3.1790428, 51.444425],
#       [-3.1790313, 51.4444551],
#       [-3.1790258, 51.4444543],
#       [-3.1790067, 51.4445041],
#       [-3.1791242, 51.4445217],
#       [-3.179143, 51.4444727],
#       [-3.1791374, 51.4444718],
#       [-3.1791493, 51.4444403],
#       [-3.1791366, 51.4444384]]]},
#    'properties': {'osid': '0000088b-0635-46d6-9ce8-4d61de6eef11',
#     'toid': 'osgb1000027214109',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 74.27215,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1999-01-15',
#     'height_evidencedate': '2021-06-08',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1999-01-15',
#     'absoluteheightmaximum': 23.23,
#     'absoluteheightminimum': 12.55,
#     'geometry_evidencedate': '1999-01-15',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 10.68,
#     'absoluteheightroofbase': 21.27,
#     'description_updatedate': '1999-01-15',
#     'oslandcover_updatedate': '1999-01-15',
#     'oslanduse_evidencedate': '1999-01-15',
#     'relativeheightroofbase': 8.72,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1999-01-15',
#     'description_evidencedate': '1999-01-15',
#     'oslandcover_evidencedate': '1999-01-15',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000008eb-0530-43ff-8b5a-0f42abaacb44',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-4.6115274, 50.4841894],
#       [-4.6115296, 50.4842195],
#       [-4.6116676, 50.4842154],
#       [-4.6116654, 50.4841853],
#       [-4.6115274, 50.4841894]]]},
#    'properties': {'osid': '000008eb-0530-43ff-8b5a-0f42abaacb44',
#     'toid': 'osgb5000005264183604',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-18',
#     'geometry_area': 32.868853,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2020-05-07',
#     'height_evidencedate': '2021-04-25',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2020-05-07',
#     'absoluteheightmaximum': 161.57,
#     'absoluteheightminimum': 157.74,
#     'geometry_evidencedate': '2019-06-22',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 3.83,
#     'absoluteheightroofbase': 159.85,
#     'description_updatedate': '2020-05-07',
#     'oslandcover_updatedate': '2020-05-07',
#     'oslanduse_evidencedate': '2019-06-22',
#     'relativeheightroofbase': 2.11,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2020-05-07',
#     'description_evidencedate': '2019-06-22',
#     'oslandcover_evidencedate': '2019-06-22',
#     'versionavailablefromdate': '2022-09-19T00:00:00Z'}},
#   {'id': '0000090e-dabd-472b-abb6-6087657da4f4',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-3.1983437, 51.7961996],
#       [-3.1983613, 51.7962473],
#       [-3.1984671, 51.7962343],
#       [-3.1984584, 51.7962047],
#       [-3.1983969, 51.7962117],
#       [-3.1983918, 51.7961941],
#       [-3.1983437, 51.7961996]]]},
#    'properties': {'osid': '0000090e-dabd-472b-abb6-6087657da4f4',
#     'toid': 'osgb5000005191214942',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 32.16917,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2016-09-13',
#     'height_evidencedate': '2021-06-13',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '2016-09-13',
#     'absoluteheightmaximum': 377.13,
#     'absoluteheightminimum': 375.15,
#     'geometry_evidencedate': '2014-06-19',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 1.98,
#     'absoluteheightroofbase': 375.36,
#     'description_updatedate': '2016-09-13',
#     'oslandcover_updatedate': '2016-09-13',
#     'oslanduse_evidencedate': '2014-06-19',
#     'relativeheightroofbase': 0.21,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2016-10-05',
#     'description_evidencedate': '2014-06-19',
#     'oslandcover_evidencedate': '2014-06-19',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000009b2-8734-472b-ac00-09b00330b8ce',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.6812167, 52.6218392],
#       [-1.6812564, 52.6218467],
#       [-1.681278, 52.6218015],
#       [-1.6812376, 52.6217946],
#       [-1.6812167, 52.6218392]]]},
#    'properties': {'osid': '000009b2-8734-472b-ac00-09b00330b8ce',
#     'toid': 'osgb1000025436801',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 14.69285,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1990-06-22',
#     'height_evidencedate': '2022-02-27',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1990-06-22',
#     'absoluteheightmaximum': 68.4,
#     'absoluteheightminimum': 66.29,
#     'geometry_evidencedate': '1990-06-22',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 2.11,
#     'absoluteheightroofbase': 68.0,
#     'description_updatedate': '1990-06-22',
#     'oslandcover_updatedate': '1990-06-22',
#     'oslanduse_evidencedate': '1990-06-22',
#     'relativeheightroofbase': 1.71,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1990-06-22',
#     'description_evidencedate': '1990-06-22',
#     'oslandcover_evidencedate': '1990-06-22',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000009cd-a51b-460e-a6f9-38d6397c391a',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-3.4133561, 56.4213989],
#       [-3.4133704, 56.4214004],
#       [-3.4134664, 56.421411],
#       [-3.4134782, 56.4213786],
#       [-3.4135221, 56.4213834],
#       [-3.4135589, 56.4212815],
#       [-3.4134189, 56.421266],
#       [-3.4133821, 56.4213679],
#       [-3.4133679, 56.4213663],
#       [-3.4133561, 56.4213989]]]},
#    'properties': {'osid': '000009cd-a51b-460e-a6f9-38d6397c391a',
#     'toid': 'osgb1000039390288',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 127.527975,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2021-01-08',
#     'height_evidencedate': '2020-09-27',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2005-12-12',
#     'absoluteheightmaximum': 61.93,
#     'absoluteheightminimum': 56.08,
#     'geometry_evidencedate': '2020-09-27',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 5.85,
#     'absoluteheightroofbase': 59.3,
#     'description_updatedate': '2005-12-12',
#     'oslandcover_updatedate': '2005-12-12',
# ...
#     'relativeheightroofbase': 2.6,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1991-11-01',
#     'description_evidencedate': '1991-11-01',
#     'oslandcover_evidencedate': '1991-11-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00001e53-bfe2-4e1c-942e-c1d1462b1df6',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-3.9878087, 55.9870616],
#       [-3.9879498, 55.9871576],
#       [-3.9879296, 55.987167],
#       [-3.987927, 55.9871913],
#       [-3.9879383, 55.9871991],
#       [-3.9878861, 55.987223],
#       [-3.9879002, 55.9872326],
#       [-3.9879607, 55.9872739],
#       [-3.9880579, 55.9872301],
#       [-3.9881409, 55.9871919],
#       [-3.988042, 55.987125],
#       [-3.9880254, 55.9871138],
#       [-3.9878917, 55.9870234],
#       [-3.9878087, 55.9870616]]]},
#    'properties': {'osid': '00001e53-bfe2-4e1c-942e-c1d1462b1df6',
#     'toid': 'osgb1000041044106',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 229.934179,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2020-03-24',
#     'height_evidencedate': '2022-06-20',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2006-08-30',
#     'absoluteheightmaximum': 83.22,
#     'absoluteheightminimum': 73.86,
#     'geometry_evidencedate': '2019-09-20',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.36,
#     'absoluteheightroofbase': 79.83,
#     'description_updatedate': '2006-08-30',
#     'oslandcover_updatedate': '2006-08-30',
#     'oslanduse_evidencedate': '2006-08-30',
#     'relativeheightroofbase': 5.97,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-03-01',
#     'description_evidencedate': '2006-08-30',
#     'oslandcover_evidencedate': '2006-08-30',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00001f4d-59e4-4046-8533-43ae6cfbc476',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-0.2395428, 51.413569],
#       [-0.2393754, 51.4135854],
#       [-0.239381, 51.4136071],
#       [-0.2393695, 51.4136078],
#       [-0.2393636, 51.4136122],
#       [-0.2393672, 51.4136302],
#       [-0.2393778, 51.4136335],
#       [-0.2393865, 51.4136332],
#       [-0.2393883, 51.4136418],
#       [-0.2394518, 51.413636],
#       [-0.2394529, 51.4136441],
#       [-0.239559, 51.4136349],
#       [-0.2395505, 51.4136005],
#       [-0.2395428, 51.413569]]]},
#    'properties': {'osid': '00001f4d-59e4-4046-8533-43ae6cfbc476',
#     'toid': 'osgb1000041519123',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 85.86195,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2014-09-24',
#     'height_evidencedate': '2021-04-17',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1970-01-01',
#     'absoluteheightmaximum': 26.47,
#     'absoluteheightminimum': 16.76,
#     'geometry_evidencedate': '2013-07-19',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.71,
#     'absoluteheightroofbase': 22.45,
#     'description_updatedate': '1970-01-01',
#     'oslandcover_updatedate': '1970-01-01',
#     'oslanduse_evidencedate': '1970-01-01',
#     'relativeheightroofbase': 5.69,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '1970-01-01',
#     'oslandcover_evidencedate': '1970-01-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00001fb0-4d89-446c-afaa-cce36e5fb741',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.3582615, 54.5836297],
#       [-1.3582688, 54.5836059],
#       [-1.3582426, 54.5836031],
#       [-1.358236, 54.5836273],
#       [-1.3582615, 54.5836297]]]},
#    'properties': {'osid': '00001fb0-4d89-446c-afaa-cce36e5fb741',
#     'toid': 'osgb1000030917635',
#     'theme': 'Buildings',
#     'changetype': 'Modified Attributes',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-09-18',
#     'geometry_area': 4.5975,
#     'height_source': None,
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': None,
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1984-12-10',
#     'height_evidencedate': None,
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1984-12-10',
#     'absoluteheightmaximum': None,
#     'absoluteheightminimum': None,
#     'geometry_evidencedate': '1984-12-10',
#     'heightconfidencelevel': None,
#     'relativeheightmaximum': None,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '1984-12-10',
#     'oslandcover_updatedate': '1984-12-10',
#     'oslanduse_evidencedate': '1984-12-10',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1984-12-10',
#     'description_evidencedate': '1984-12-10',
#     'oslandcover_evidencedate': '1984-12-10',
#     'versionavailablefromdate': '2022-09-19T00:00:00Z'}},
#   {'id': '00001fbd-ba1b-4f82-8820-c81ef8c484f8',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-2.5115527, 51.2294311],
#       [-2.5115169, 51.2294444],
#       [-2.5115036, 51.2294299],
#       [-2.5114545, 51.2294446],
#       [-2.5114743, 51.229459],
#       [-2.5114316, 51.2294758],
#       [-2.5114732, 51.2295184],
#       [-2.5114974, 51.2295426],
#       [-2.5116173, 51.2294954],
#       [-2.5115527, 51.2294311]]]},
#    'properties': {'osid': '00001fbd-ba1b-4f82-8820-c81ef8c484f8',
#     'toid': 'osgb1000015197850',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 92.0069,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2004-06-03',
#     'height_evidencedate': '2022-07-16',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2004-06-03',
#     'absoluteheightmaximum': 212.12,
#     'absoluteheightminimum': 205.31,
#     'geometry_evidencedate': '2004-06-03',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 6.81,
#     'absoluteheightroofbase': 207.13,
#     'description_updatedate': '2004-06-03',
#     'oslandcover_updatedate': '2004-06-03',
#     'oslanduse_evidencedate': '2004-06-03',
#     'relativeheightroofbase': 1.82,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-07-22',
#     'description_evidencedate': '2004-06-03',
#     'oslandcover_evidencedate': '2004-06-03',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000020a3-793a-4a24-bdbb-58c39c0ca2ae',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[0.1020536, 53.170151],
#       [0.1021367, 53.1701359],
#       [0.1021571, 53.1701765],
#       [0.102074, 53.1701916],
#       [0.1020536, 53.170151]]]},
#    'properties': {'osid': '000020a3-793a-4a24-bdbb-58c39c0ca2ae',
#     'toid': 'osgb1000002491606250',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Archway',
#     'versiondate': '2022-08-26',
#     'geometry_area': 27.37145,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Level 1',
#     'oslandusetiera': 'Unknown Or Unused Artificial',
#     'oslandusetierb': [],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2005-11-28',
#     'height_evidencedate': '2022-04-21',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2005-11-28',
#     'absoluteheightmaximum': 43.23,
#     'absoluteheightminimum': 35.88,
#     'geometry_evidencedate': '2005-11-28',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 7.35,
#     'absoluteheightroofbase': 39.26,
#     'description_updatedate': '2005-11-28',
#     'oslandcover_updatedate': '2005-11-28',
#     'oslanduse_evidencedate': '2005-11-28',
#     'relativeheightroofbase': 3.38,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2003-06-09',
#     'description_evidencedate': '2005-11-28',
#     'oslandcover_evidencedate': '2005-11-28',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '00002169-5016-43a6-8ab8-cb56082de768',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-1.3595756, 53.7444133],
#       [-1.3595624, 53.7444267],
#       [-1.3595619, 53.7444266],
#       [-1.3595128, 53.7444775],
#       [-1.3596247, 53.7445162],
#       [-1.3596647, 53.7444756],
#       [-1.3596568, 53.7444728],
#       [-1.3596799, 53.7444494],
#       [-1.3595756, 53.7444133]]]},
#    'properties': {'osid': '00002169-5016-43a6-8ab8-cb56082de768',
#     'toid': 'osgb1000002068897577',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 68.950963,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '2019-07-03',
#     'height_evidencedate': '2021-04-19',
#     'capturespecification': 'Rural',
#     'oslanduse_updatedate': '2007-10-18',
#     'absoluteheightmaximum': 29.02,
#     'absoluteheightminimum': 19.55,
#     'geometry_evidencedate': '2019-03-29',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.47,
#     'absoluteheightroofbase': 26.85,
#     'description_updatedate': '2007-10-18',
#     'oslandcover_updatedate': '2007-10-18',
#     'oslanduse_evidencedate': '2007-10-18',
#     'relativeheightroofbase': 7.3,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '2005-06-03',
#     'description_evidencedate': '2007-10-18',
#     'oslandcover_evidencedate': '2007-10-18',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000021a5-c2a9-4155-9cf3-b6da7916896e',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-0.2057562, 51.6428673],
#       [-0.2057538, 51.6428182],
#       [-0.2056316, 51.6428213],
#       [-0.2056356, 51.6429028],
#       [-0.2056898, 51.6429018],
#       [-0.2056902, 51.6429103],
#       [-0.2057582, 51.6429091],
#       [-0.2057562, 51.6428673]]]},
#    'properties': {'osid': '000021a5-c2a9-4155-9cf3-b6da7916896e',
#     'toid': 'osgb1000042135917',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 81.62875,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1993-04-01',
#     'height_evidencedate': '2021-04-18',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1993-04-01',
#     'absoluteheightmaximum': 95.44,
#     'absoluteheightminimum': 86.29,
#     'geometry_evidencedate': '1993-04-01',
#     'heightconfidencelevel': 'Not Assessed',
#     'relativeheightmaximum': 9.15,
#     'absoluteheightroofbase': 92.13,
#     'description_updatedate': '1993-04-01',
#     'oslandcover_updatedate': '1993-04-01',
#     'oslanduse_evidencedate': '1993-04-01',
#     'relativeheightroofbase': 5.84,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1993-04-01',
#     'description_evidencedate': '1993-04-01',
#     'oslandcover_evidencedate': '1993-04-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}},
#   {'id': '000021e7-1718-4db5-bf97-9f4d884963a7',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-4.159358, 51.676436],
#       [-4.1593328, 51.6764531],
#       [-4.1593752, 51.6764775],
#       [-4.1593359, 51.6765043],
#       [-4.1594058, 51.6765443],
#       [-4.1594696, 51.6765013],
#       [-4.159358, 51.676436]]]},
#    'properties': {'osid': '000021e7-1718-4db5-bf97-9f4d884963a7',
#     'toid': 'osgb1000021723740',
#     'theme': 'Buildings',
#     'changetype': 'New',
#     'isobscured': False,
#     'description': 'Building',
#     'versiondate': '2022-08-26',
#     'geometry_area': 53.39125,
#     'height_source': 'Ordnance Survey',
#     'physicallevel': 'Surface Level',
#     'oslandusetiera': 'Residential Accommodation',
#     'oslandusetierb': ['Private Residence'],
#     'geometry_source': 'Ordnance Survey',
#     'oslandcovertiera': 'Constructed',
#     'oslandcovertierb': ['Building'],
#     'oslanduse_source': 'Ordnance Survey',
#     'height_updatedate': '2022-08-24',
#     'description_source': 'Ordnance Survey',
#     'oslandcover_source': 'Ordnance Survey',
#     'associatedstructure': None,
#     'geometry_updatedate': '1970-01-01',
#     'height_evidencedate': '2021-04-10',
#     'capturespecification': 'Urban',
#     'oslanduse_updatedate': '1970-01-01',
#     'absoluteheightmaximum': 14.21,
#     'absoluteheightminimum': 6.69,
#     'geometry_evidencedate': '1970-01-01',
#     'heightconfidencelevel': 'Incomplete',
#     'relativeheightmaximum': 7.52,
#     'absoluteheightroofbase': None,
#     'description_updatedate': '1970-01-01',
#     'oslandcover_updatedate': '1970-01-01',
#     'oslanduse_evidencedate': '1970-01-01',
#     'relativeheightroofbase': None,
#     'versionavailabletodate': None,
#     'firstdigitalcapturedate': '1970-01-01',
#     'description_evidencedate': '1970-01-01',
#     'oslandcover_evidencedate': '1970-01-01',
#     'versionavailablefromdate': '2022-08-27T00:00:00Z'}}]}

# %% [markdown]
# The API returns an OGC-compliant GeoJSON, easy for importing into other libraries for analysis. For example, in order to import into `geopandas`:

# %%
import geopandas as gpd

gdf = gpd.GeoDataFrame.from_features(features)
gdf.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((-3.97031 55.74255, -3.97019 55.74249...
# 1  POLYGON ((1.72756 52.66142, 1.72755 52.66144, ...
# 2  POLYGON ((0.19415 51.59241, 0.19411 51.59241, ...
# 3  POLYGON ((-1.45472 52.39610, -1.45479 52.39613...
# 4  POLYGON ((0.93898 52.81772, 0.93900 52.81767, ...
#
#                                    osid                  toid      theme  \
# 0  000000b1-0556-4231-a52a-9b5b8b82dfbf     osgb1000041024621  Buildings
# 1  00000183-3ae0-4f05-adb8-a5792d09f55f  osgb5000005167584940  Buildings
# 2  000001d6-8217-4f7a-a70e-3757eb76c9e4     osgb1000000360448  Buildings
# 3  00000208-a659-49f9-a587-ab26cb2b2248     osgb1000017249389  Buildings
# 4  00000246-42c8-4e23-982e-15613e0fd2fe     osgb1000008341371  Buildings
#
#             changetype  isobscured description versiondate  geometry_area  \
# 0  Modified Attributes       False    Building  2022-09-18      59.200650
# 1                  New       False    Building  2022-08-26       9.499142
# 2                  New       False    Building  2022-08-26      15.258750
# 3                  New       False    Building  2022-08-26      12.806250
# 4                  New       False    Building  2022-08-26      58.280086
#
#      height_source  ... absoluteheightroofbase description_updatedate  \
# 0  Ordnance Survey  ...                 110.85             2006-08-30
# 1  Ordnance Survey  ...                   6.21             2015-10-29
# 2  Ordnance Survey  ...                  37.13             1993-04-01
# 3  Ordnance Survey  ...                  71.95             1993-05-01
# 4  Ordnance Survey  ...                  54.46             2005-04-30
#
#   oslandcover_updatedate oslanduse_evidencedate relativeheightroofbase  \
# 0             2006-08-30             2006-08-30                   5.85
# 1             2015-10-29             2015-03-11                   0.82
# 2             1993-04-01             1993-04-01                   2.43
# 3             1993-05-01             1993-05-01                   1.96
# 4             2005-04-30             2005-04-30                   3.61
#
#   versionavailabletodate firstdigitalcapturedate description_evidencedate  \
# 0                   None              1991-09-18               2006-08-30
# 1                   None              2015-11-12               2015-03-11
# 2                   None              1993-04-01               1993-04-01
# 3                   None              1993-05-01               1993-05-01
# 4                   None              1992-03-13               2005-04-30
#
#   oslandcover_evidencedate versionavailablefromdate
# 0               2006-08-30     2022-09-19T00:00:00Z
# 1               2015-03-11     2022-08-27T00:00:00Z
# 2               1993-04-01     2022-08-27T00:00:00Z
# 3               1993-05-01     2022-08-27T00:00:00Z
# 4               2005-04-30     2022-08-27T00:00:00Z
#
# [5 rows x 40 columns]

# %% [markdown]
# You can learn more about importing data from the `osdatahub` package into other common Python libraries [in this example](https://github.com/OrdnanceSurvey/osdatahub/blob/master/Examples/Plotting%20API%20Results%20-%20GeoPandas%2C%20Matplotlib%20and%20Contextily.ipynb).

# %% [markdown]
# ## Adding Filters
#
# There are many options for filtering your NGD query, using the following attributes:
#
# * `extent` - you can specify any polygon to query by using the `Extent` class. You can learn more about using `Extent` [here](https://github.com/OrdnanceSurvey/osdatahub/blob/master/Examples/Defining%20Extents%20for%20API%20Queries.ipynb)
# * `start_datetime` and `end_datetime` - if you want to only get features that have a temporal property, you can specify date ranges to query within. If you want to get features for a single time, simply provide the same argument for both parameters.
# * `cql_filter` - The NGD API supports a generic filter grammar called the Common Query Language (CQL) to further filter your query using human readable commands. You can find out more about the operations that the API supports in the Queryables section of the [Technical Specification](https://osdatahub.os.uk/docs/ofa/technicalSpecification). The CQL filter allows you to specify specific properties for features as well as spatial filters.
# * `max_results` - Allows you to specify the maximum number of features you'd like to receive.
# * `offset` - Skips past the specified number of features in the collection.
#
# In our case, we want to get features that are only within a certain bounding box in Manchester. We can do this by specifying an extent:

# %%
from osdatahub import Extent

extent = Extent.from_bbox((-2.244973,53.476620,-2.237799,53.480525), crs="EPSG:4326")
features = ngd.query(extent=extent)
features
# Out:
# ERROR:root:{
#     "code": 400,
#     "description": "Intersection geometry 'POLYGON ((-2.237799 53.47662, -2.237799 53.480525, -2.244973 53.480525, -2.244973 53.47662, -2.237799 53.47662))' is outside the spatial extent of collection 'Building Part'. If the given geometry is within a supported CRS, please use the filter-crs parameter. The following coordinate reference systems are supported: http://www.opengis.net/def/crs/OGC/1.3/CRS84, http://www.opengis.net/def/crs/EPSG/0/27700, http://www.opengis.net/def/crs/EPSG/0/4326, http://www.opengis.net/def/crs/EPSG/0/3857",
#     "help": "https://osdatahub.os.uk/docs/ofa/technicalSpecification"
# }
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       1 from osdatahub import Extent
#       3 extent = Extent.from_bbox((-2.244973,53.476620,-2.237799,53.480525), crs="EPSG:4326")
# ----> 4 features = ngd.query(extent=extent)
#       5 features
#
# File ~/miniconda3/envs/osdatahub/lib/python3.10/site-packages/osdatahub/NGD/ngd_api.py:175, in NGD.query(self, extent, crs, start_datetime, end_datetime, cql_filter, filter_crs, max_results, offset)
#     173 except requests.exceptions.HTTPError as e:
#     174     logging.error(json.dumps(e.response.json(), indent=4))
# --> 175     raise e
#     177 resp_json = response.json()
#     179 data = _merge_geojsons(data, resp_json)
#
# File ~/miniconda3/envs/osdatahub/lib/python3.10/site-packages/osdatahub/NGD/ngd_api.py:172, in NGD.query(self, extent, crs, start_datetime, end_datetime, cql_filter, filter_crs, max_results, offset)
#     170 try:
#     171     response = requests.get(self.__endpoint(), params=params, headers={"key": self.key})
# --> 172     response.raise_for_status()
#     173 except requests.exceptions.HTTPError as e:
#     174     logging.error(json.dumps(e.response.json(), indent=4))
#
# File ~/miniconda3/envs/osdatahub/lib/python3.10/site-packages/requests/models.py:943, in Response.raise_for_status(self)
#     940     http_error_msg = u'%s Server Error: %s for url: %s' % (self.status_code, reason, self.url)
#     942 if http_error_msg:
# --> 943     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.os.uk/features/ngd/ofa/v1/collections/bld-fts-buildingpart/items/?filter=INTERSECTS%28geometry%2C+POLYGON+%28%28-2.237799+53.47662%2C+-2.237799+53.480525%2C+-2.244973+53.480525%2C+-2.244973+53.47662%2C+-2.237799+53.47662%29%29%29&filter-crs=http%3A%2F%2Fwww.opengis.net%2Fdef%2Fcrs%2FEPSG%2F0%2F4326&limit=100&offset=0

# %%
## Basically i was just gonna add more filters, and talk about those. Intersections, choosing by properties etc.
